# %%
from new_model import *

# %%
seed = 100
random.seed(seed)
np.random.seed(seed)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(seed)
if device == 'cuda':
    torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
#Data 다운로드 경로지정
batch_size = 128


#Data Process 
transform_train = transforms.Compose([transforms.RandomCrop(32, padding=4),transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(),transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))]) 

transform_val = transforms.Compose([transforms.ToTensor(), 
                                    transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010))])

transform_test = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010))])

train_CIFAR10 = torchvision.datasets.CIFAR10(root='../data', train=True, download=True, transform=transform_train)

test_CIFAR10 = torchvision.datasets.CIFAR10(root='../data', train=False, download=True, transform=transform_test)

num_train = int(1.0 * len(train_CIFAR10) * 95 / 100)
num_val = len(train_CIFAR10) - num_train
train_CIFAR10, val_CIFAR10 = torch.utils.data.random_split(train_CIFAR10, [num_train, num_val])

train_loader = torch.utils.data.DataLoader(train_CIFAR10, batch_size=batch_size, shuffle=True, num_workers=2) #num_workers는 데이터 로드시 sub process 몇개 쓸거냐 
val_loader = torch.utils.data.DataLoader(val_CIFAR10, batch_size=batch_size,shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_CIFAR10, batch_size=batch_size, shuffle=True, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
#CIFAR 100 : Data 다운로드 경로지정
batch_size = 128

#Data Process
transform_train = transforms.Compose([transforms.RandomCrop(32, padding=4),transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(),transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))]) 

transform_val = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))]) 

transform_test = transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))]) 

train_CIFAR100 = torchvision.datasets.CIFAR100(root='../data', train=True, download=True, transform=transform_train)

test_CIFAR100 = torchvision.datasets.CIFAR100(root='../data', train=False, download=True, transform=transform_test)

num_train = int(1.0 * len(train_CIFAR100) * 95 / 100)
num_val = len(train_CIFAR100) - num_train
train_CIFAR100, val_CIFAR100 = torch.utils.data.random_split(train_CIFAR100, [num_train, num_val])

train_loader = torch.utils.data.DataLoader(train_CIFAR100, batch_size=batch_size, shuffle=True, num_workers=2) #num_workers는 데이터 로드시 sub process 몇개 쓸거냐 
val_loader = torch.utils.data.DataLoader(val_CIFAR100, batch_size=batch_size,shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_CIFAR100, batch_size=batch_size, shuffle=True, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def node_prune(model, pruning_ratio):
    for layer in model.modules():
        if isinstance(layer, M_BasicBlock):
            # calculate cutoff value
            nonzero_vals = layer.get_2norm()[0][layer.M_relu1.active != 0]
            cutoff1 = torch.quantile(nonzero_vals, pruning_ratio)

            # set inactive nodes to 0
            layer.M_relu1.active.data[layer.get_2norm()[0] < cutoff1] *= 0
            
            # calculate cutoff value
            nonzero_vals = layer.get_2norm()[1][layer.M_relu2.active != 0]
            cutoff2 = torch.quantile(nonzero_vals, pruning_ratio)

            # set inactive nodes to 0
            layer.M_relu2.active.data[layer.get_2norm()[1] < cutoff2] *= 0

# %%
## fine_tuning
def fine_tuning(model, mode, EPOCHS, INITIAL_LR):
    # total number of training epochs
    CHECKPOINT_PATH = "./save_seed100_CIFAR100"

    best_val_acc = 0
    current_learning_rate = INITIAL_LR
    
    remaining_node1 = sum([sum(layer.M_relu1.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
    remaining_node2 = sum([sum(layer.M_relu2.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
    print(f'최초 node의 갯수 : {remaining_node1, remaining_node2}')    

    print("==> Training starts!")
    start = time.time()
    optimizer = torch.optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)
    scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[60, 120, 160], gamma=0.2)
    # scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=0)    
    for i in range(EPOCHS):
        if i % 40 == 0 :
            print(f'{(i//40)+1}번 자르고 fine tuning을 시작합니다.')
            node_prune(model, ratio)
            
            remaining_node1 = sum([sum(layer.M_relu1.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
            remaining_node2 = sum([sum(layer.M_relu2.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])

            print(f'{(i//40)+1}번 pruning 이후 남은 node 는 : {(remaining_node1, remaining_node2)}')
        
        '''
        train loop
        '''            
        model.train()
        
        # this help you compute the training accuracy
        total_examples = 0
        correct_examples = 0

        train_loss = 0 # track training loss if you want

        # Train the model for 1 epoch.
        for batch_idx, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.to(device).float(), targets.to(device).long() #inputs과 targets는 gpu로 계산

            # compute the output and loss
            y_preds = model(inputs)        
            loss = criterion(y_preds,targets)
            train_loss += loss.item()

            # zero the gradient
            optimizer.zero_grad()

            # backpropagation
            loss.backward()

            # apply gradient and update the weights
            optimizer.step()

            # count the number of correctly predicted samples in the current batch
            y_preds_class = torch.argmax(y_preds, dim=1)
            correct_examples += (targets == y_preds_class).sum().item()
            total_examples += targets.size(0)

        scheduler.step()    #스케쥴러 사용해보기
            
        avg_loss_tr = train_loss / len(train_loader) ###
        avg_acc_tr = correct_examples / total_examples ### 

                                                      
        '''
        validation loop
        '''
                                                      
        # switch to eval mode
        model.eval()
        total_examples = 0
        correct_examples = 0
        val_loss = 0 # again, track the validation loss if you want
        
        # disable gradient during validation, which can save GPU memory
        with torch.no_grad():
            for batch_idx, (inputs, targets) in enumerate(val_loader):
                inputs, targets = inputs.to(device).float(), targets.to(device).long()

                # compute the output and loss
                y_preds = model(inputs)        
                loss = criterion(y_preds,targets)
                val_loss += loss.item()

                # count the number of correctly predicted samples in the current batch
                y_preds_class = torch.argmax(y_preds, dim=1)
                correct_examples += (targets == y_preds_class).sum().item()
                total_examples += targets.size(0)

        avg_loss_val = val_loss / len(val_loader)
        avg_acc_val = correct_examples / total_examples

                                                      
        # save the model checkpoint
        if avg_acc_val > best_val_acc:
            best_val_acc = avg_acc_val
            if not os.path.exists(CHECKPOINT_PATH):
                os.makedirs(CHECKPOINT_PATH)

            state = {'state_dict': model.state_dict(),
                     'epoch': i,
                     'lr': current_learning_rate}
            
            torch.save(state, os.path.join(CHECKPOINT_PATH, '{}.pth'.format(mode)))        
    
        if i % 10 == 9 :  
            end = time.time()
            diff_time = round(end - start,2)
            print("Epoch %d:" %(i+1), f"progress time is {diff_time} sec")
            print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss_val, avg_acc_val))
    print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")                       

    return model

# %%
###8. test_model
def test_model(model):
    model.to(device)
    model.eval()

    total_examples = 0
    correct_examples = 0
    softmax = torch.nn.Softmax(dim=1)

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(test_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            pred = model(inputs)
            total_examples += inputs.shape[0]

            out = softmax(pred)
            out = torch.max(out, 1)

            correct_examples += torch.sum(targets==out[1]).cpu().data.numpy().tolist()

    avg_acc = correct_examples / total_examples
    print("Total examples is {}, correct examples is {}; Test accuracy: {}".format(total_examples, correct_examples, avg_acc))

# %% [markdown]
# ## 모델지정

# %%
device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")

MOMENTUM = 0.9

REG = 5e-4

criterion = nn.CrossEntropyLoss()

ratio = 1-0.2**0.1988

basic = 10

# %%
for lr in [0.004, 0.02]:
    model = Wide_ResNet(28, basic, 0.3, 100).to(device)        
    ## train
    checkpoint = torch.load(f"../1.Wide_ResNet_model/saved_model/WR_28x{basic}_cifar100.pth")
    model.load_state_dict(checkpoint['state_dict'])

    fine_tuning(model, mode=f"28x{basic}_0.8_multistepLR_lr{lr}", EPOCHS=200, INITIAL_LR=lr)

    ## test
    checkpoint_path = f"./save_seed{seed}_CIFAR100/28x{basic}_0.8_multistepLR_lr{lr}.pth"
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['state_dict'])
    test_model(model)
# Out:
# | Wide-Resnet 28x10
# 최초 node의 갯수 : (tensor(4480., device='cuda:3'), tensor(4480., device='cuda:3'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 pruning 이후 남은 node 는 : (tensor(3252., device='cuda:3'), tensor(3252., device='cuda:3'))
# Epoch 10: progress time is 2705.13 sec
# Validation loss: 0.1239, Validation accuracy: 0.9732
# Epoch 20: progress time is 5393.93 sec
# Validation loss: 0.1250, Validation accuracy: 0.9760
# Epoch 30: progress time is 8081.04 sec
# Validation loss: 0.1627, Validation accuracy: 0.9620
# Epoch 40: progress time is 10768.29 sec
# Validation loss: 0.2484, Validation accuracy: 0.9364
# 2번 자르고 fine tuning을 시작합니다.
# 2번 pruning 이후 남은 node 는 : (tensor(2356., device='cuda:3'), tensor(2356., device='cuda:3'))
# Epoch 50: progress time is 13452.15 sec
# Validation loss: 0.7543, Validation accuracy: 0.8028
# Epoch 60: progress time is 16135.2 sec
# Validation loss: 0.7121, Validation accuracy: 0.8112
# Epoch 70: progress time is 18818.56 sec
# Validation loss: 0.5387, Validation accuracy: 0.8564
# Epoch 80: progress time is 21502.86 sec
# Validation loss: 0.5377, Validation accuracy: 0.8588
# 3번 자르고 fine tuning을 시작합니다.
# 3번 pruning 이후 남은 node 는 : (tensor(1708., device='cuda:3'), tensor(1708., device='cuda:3'))
# Epoch 90: progress time is 24182.23 sec
# Validation loss: 0.8432, Validation accuracy: 0.7856
# Epoch 100: progress time is 26861.06 sec
# Validation loss: 0.7908, Validation accuracy: 0.7984
# Epoch 110: progress time is 29539.29 sec
# Validation loss: 0.7896, Validation accuracy: 0.7956
# Epoch 120: progress time is 32218.98 sec
# Validation loss: 0.7980, Validation accuracy: 0.8000
# 4번 자르고 fine tuning을 시작합니다.
# 4번 pruning 이후 남은 node 는 : (tensor(1236., device='cuda:3'), tensor(1236., device='cuda:3'))
# Epoch 130: progress time is 34897.12 sec
# Validation loss: 1.0806, Validation accuracy: 0.7296
# Epoch 140: progress time is 37575.66 sec
# Validation loss: 1.0812, Validation accuracy: 0.7352
# Epoch 150: progress time is 40253.3 sec
# Validation loss: 1.0182, Validation accuracy: 0.7500
# Epoch 160: progress time is 42928.06 sec
# Validation loss: 1.0016, Validation accuracy: 0.7536
# 5번 자르고 fine tuning을 시작합니다.
# 5번 pruning 이후 남은 node 는 : (tensor(896., device='cuda:3'), tensor(896., device='cuda:3'))
# Epoch 170: progress time is 45600.74 sec
# Validation loss: 1.5221, Validation accuracy: 0.6160
# Epoch 180: progress time is 48271.87 sec
# Validation loss: 1.3717, Validation accuracy: 0.6560
# Epoch 190: progress time is 50941.31 sec
# Validation loss: 1.2886, Validation accuracy: 0.6728
# Epoch 200: progress time is 53612.4 sec
# Validation loss: 1.2717, Validation accuracy: 0.6888
# ==> Optimization finished! Best validation accuracy: 0.9792
# Total examples is 10000, correct examples is 7768; Test accuracy: 0.7768
# | Wide-Resnet 28x10
# 최초 node의 갯수 : (tensor(4480., device='cuda:3'), tensor(4480., device='cuda:3'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 pruning 이후 남은 node 는 : (tensor(3252., device='cuda:3'), tensor(3252., device='cuda:3'))
# Epoch 10: progress time is 2688.91 sec
# Validation loss: 0.8801, Validation accuracy: 0.7612
# Epoch 20: progress time is 5376.2 sec
# Validation loss: 0.8941, Validation accuracy: 0.7588
# Epoch 30: progress time is 8063.25 sec
# Validation loss: 0.9439, Validation accuracy: 0.7468
# Epoch 40: progress time is 10750.79 sec
# Validation loss: 0.9487, Validation accuracy: 0.7524
# 2번 자르고 fine tuning을 시작합니다.
# 2번 pruning 이후 남은 node 는 : (tensor(2356., device='cuda:3'), tensor(2356., device='cuda:3'))
# Epoch 50: progress time is 13435.47 sec
# Validation loss: 1.1849, Validation accuracy: 0.6960
# Epoch 60: progress time is 16118.69 sec
# Validation loss: 1.1917, Validation accuracy: 0.7028
# Epoch 70: progress time is 18805.3 sec
# Validation loss: 0.7656, Validation accuracy: 0.8076
# Epoch 80: progress time is 21488.21 sec
# Validation loss: 0.7414, Validation accuracy: 0.8052
# 3번 자르고 fine tuning을 시작합니다.
# 3번 pruning 이후 남은 node 는 : (tensor(1708., device='cuda:3'), tensor(1708., device='cuda:3'))
# Epoch 90: progress time is 24167.08 sec
# Validation loss: 1.0860, Validation accuracy: 0.7332
# Epoch 100: progress time is 26847.54 sec
# Validation loss: 1.0733, Validation accuracy: 0.7400
# Epoch 110: progress time is 29525.02 sec
# Validation loss: 1.0962, Validation accuracy: 0.7412
# Epoch 120: progress time is 32204.86 sec
# Validation loss: 1.0897, Validation accuracy: 0.7384
# 4번 자르고 fine tuning을 시작합니다.
# 4번 pruning 이후 남은 node 는 : (tensor(1236., device='cuda:3'), tensor(1236., device='cuda:3'))
# Epoch 130: progress time is 34884.58 sec
# Validation loss: 1.1389, Validation accuracy: 0.7200
# Epoch 140: progress time is 37560.11 sec
# Validation loss: 1.1946, Validation accuracy: 0.7276
# Epoch 150: progress time is 40236.52 sec
# Validation loss: 1.1540, Validation accuracy: 0.7256
# Epoch 160: progress time is 42915.49 sec
# Validation loss: 1.1660, Validation accuracy: 0.7340
# 5번 자르고 fine tuning을 시작합니다.
# 5번 pruning 이후 남은 node 는 : (tensor(896., device='cuda:3'), tensor(896., device='cuda:3'))
# Epoch 170: progress time is 45592.08 sec
# Validation loss: 1.5430, Validation accuracy: 0.6104
# Epoch 180: progress time is 48264.47 sec
# Validation loss: 1.3079, Validation accuracy: 0.6792
# Epoch 190: progress time is 50935.98 sec
# Validation loss: 1.2884, Validation accuracy: 0.6800
# Epoch 200: progress time is 53607.47 sec
# Validation loss: 1.2515, Validation accuracy: 0.6936
# ==> Optimization finished! Best validation accuracy: 0.8088
# Total examples is 10000, correct examples is 7686; Test accuracy: 0.7686

# %% [markdown]
# # cosine scheduler

# %%
## fine_tuning
def fine_tuning(model, mode, EPOCHS, INITIAL_LR):
    # total number of training epochs
    CHECKPOINT_PATH = "./save_seed100_CIFAR100"

    best_val_acc = 0
    current_learning_rate = INITIAL_LR
    
    remaining_node1 = sum([sum(layer.M_relu1.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
    remaining_node2 = sum([sum(layer.M_relu2.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
    print(f'최초 node의 갯수 : {remaining_node1, remaining_node2}')    

    print("==> Training starts!")
    start = time.time()
    optimizer = torch.optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)
    # scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[60, 120, 160], gamma=0.2)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=0)    
    for i in range(EPOCHS):
        if i % 40 == 0 :
            print(f'{(i//40)+1}번 자르고 fine tuning을 시작합니다.')
            node_prune(model, ratio)
            
            remaining_node1 = sum([sum(layer.M_relu1.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
            remaining_node2 = sum([sum(layer.M_relu2.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])

            print(f'{(i//40)+1}번 pruning 이후 남은 node 는 : {(remaining_node1, remaining_node2)}')
        
        '''
        train loop
        '''            
        model.train()
        
        # this help you compute the training accuracy
        total_examples = 0
        correct_examples = 0

        train_loss = 0 # track training loss if you want

        # Train the model for 1 epoch.
        for batch_idx, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.to(device).float(), targets.to(device).long() #inputs과 targets는 gpu로 계산

            # compute the output and loss
            y_preds = model(inputs)        
            loss = criterion(y_preds,targets)
            train_loss += loss.item()

            # zero the gradient
            optimizer.zero_grad()

            # backpropagation
            loss.backward()

            # apply gradient and update the weights
            optimizer.step()

            # count the number of correctly predicted samples in the current batch
            y_preds_class = torch.argmax(y_preds, dim=1)
            correct_examples += (targets == y_preds_class).sum().item()
            total_examples += targets.size(0)

        scheduler.step()    #스케쥴러 사용해보기
            
        avg_loss_tr = train_loss / len(train_loader) ###
        avg_acc_tr = correct_examples / total_examples ### 

                                                      
        '''
        validation loop
        '''
                                                      
        # switch to eval mode
        model.eval()
        total_examples = 0
        correct_examples = 0
        val_loss = 0 # again, track the validation loss if you want
        
        # disable gradient during validation, which can save GPU memory
        with torch.no_grad():
            for batch_idx, (inputs, targets) in enumerate(val_loader):
                inputs, targets = inputs.to(device).float(), targets.to(device).long()

                # compute the output and loss
                y_preds = model(inputs)        
                loss = criterion(y_preds,targets)
                val_loss += loss.item()

                # count the number of correctly predicted samples in the current batch
                y_preds_class = torch.argmax(y_preds, dim=1)
                correct_examples += (targets == y_preds_class).sum().item()
                total_examples += targets.size(0)

        avg_loss_val = val_loss / len(val_loader)
        avg_acc_val = correct_examples / total_examples

                                                      
        # save the model checkpoint
        if avg_acc_val > best_val_acc:
            best_val_acc = avg_acc_val
            if not os.path.exists(CHECKPOINT_PATH):
                os.makedirs(CHECKPOINT_PATH)

            state = {'state_dict': model.state_dict(),
                     'epoch': i,
                     'lr': current_learning_rate}
            
            torch.save(state, os.path.join(CHECKPOINT_PATH, '{}.pth'.format(mode)))        
    
        if i % 10 == 9 :  
            end = time.time()
            diff_time = round(end - start,2)
            print("Epoch %d:" %(i+1), f"progress time is {diff_time} sec")
            print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss_val, avg_acc_val))
    print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")                       

    return model

# %%
for lr in [0.004, 0.02]:
    model = Wide_ResNet(28, basic, 0.3, 100).to(device)        
    ## train
    checkpoint = torch.load(f"../1.Wide_ResNet_model/saved_model/WR_28x{basic}_cifar100.pth")
    model.load_state_dict(checkpoint['state_dict'])

    fine_tuning(model, mode=f"28x{basic}_0.8_cosine_lr{lr}", EPOCHS=200, INITIAL_LR=lr)

    ## test
    checkpoint_path = f"./save_seed{seed}_CIFAR100/28x{basic}_0.8_cosine_lr{lr}.pth"
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['state_dict'])
    test_model(model)
# Out:
# | Wide-Resnet 28x10
# 최초 node의 갯수 : (tensor(4480., device='cuda:3'), tensor(4480., device='cuda:3'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 pruning 이후 남은 node 는 : (tensor(3252., device='cuda:3'), tensor(3252., device='cuda:3'))
# Epoch 10: progress time is 2689.94 sec
# Validation loss: 0.1050, Validation accuracy: 0.9768
# Epoch 20: progress time is 5376.5 sec
# Validation loss: 0.1145, Validation accuracy: 0.9756
# Epoch 30: progress time is 8061.69 sec
# Validation loss: 0.1141, Validation accuracy: 0.9780
# Epoch 40: progress time is 10746.11 sec
# Validation loss: 0.1316, Validation accuracy: 0.9716
# 2번 자르고 fine tuning을 시작합니다.
# 2번 pruning 이후 남은 node 는 : (tensor(2356., device='cuda:3'), tensor(2356., device='cuda:3'))
# Epoch 50: progress time is 13425.76 sec
# Validation loss: 0.4911, Validation accuracy: 0.8688
# Epoch 60: progress time is 16106.71 sec
# Validation loss: 0.4487, Validation accuracy: 0.8804
# Epoch 70: progress time is 18789.27 sec
# Validation loss: 0.4017, Validation accuracy: 0.8972
# Epoch 80: progress time is 21471.64 sec
# Validation loss: 0.3876, Validation accuracy: 0.8960
# 3번 자르고 fine tuning을 시작합니다.
# 3번 pruning 이후 남은 node 는 : (tensor(1708., device='cuda:3'), tensor(1708., device='cuda:3'))
# Epoch 90: progress time is 24150.33 sec
# Validation loss: 0.7274, Validation accuracy: 0.8172
# Epoch 100: progress time is 26826.1 sec
# Validation loss: 0.6780, Validation accuracy: 0.8200
# Epoch 110: progress time is 29501.41 sec
# Validation loss: 0.7676, Validation accuracy: 0.8092
# Epoch 120: progress time is 32175.29 sec
# Validation loss: 0.7702, Validation accuracy: 0.8096
# 4번 자르고 fine tuning을 시작합니다.
# 4번 pruning 이후 남은 node 는 : (tensor(1236., device='cuda:3'), tensor(1236., device='cuda:3'))
# Epoch 130: progress time is 34847.39 sec
# Validation loss: 1.1295, Validation accuracy: 0.6996
# Epoch 140: progress time is 37519.82 sec
# Validation loss: 1.2337, Validation accuracy: 0.6864
# Epoch 150: progress time is 40191.11 sec
# Validation loss: 1.3441, Validation accuracy: 0.6720
# Epoch 160: progress time is 42862.62 sec
# Validation loss: 1.2353, Validation accuracy: 0.6932
# 5번 자르고 fine tuning을 시작합니다.
# 5번 pruning 이후 남은 node 는 : (tensor(896., device='cuda:3'), tensor(896., device='cuda:3'))
# Epoch 170: progress time is 45532.84 sec
# Validation loss: 2.0737, Validation accuracy: 0.4420
# Epoch 180: progress time is 48202.71 sec
# Validation loss: 1.8878, Validation accuracy: 0.5188
# Epoch 190: progress time is 50872.04 sec
# Validation loss: 1.5006, Validation accuracy: 0.6044
# Epoch 200: progress time is 53540.3 sec
# Validation loss: 1.7300, Validation accuracy: 0.5688
# ==> Optimization finished! Best validation accuracy: 0.9812
# Total examples is 10000, correct examples is 7894; Test accuracy: 0.7894
# | Wide-Resnet 28x10
# 최초 node의 갯수 : (tensor(4480., device='cuda:3'), tensor(4480., device='cuda:3'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 pruning 이후 남은 node 는 : (tensor(3252., device='cuda:3'), tensor(3252., device='cuda:3'))
# Epoch 10: progress time is 2688.18 sec
# Validation loss: 0.9175, Validation accuracy: 0.7524
# Epoch 20: progress time is 5374.1 sec
# Validation loss: 0.8856, Validation accuracy: 0.7604
# Epoch 30: progress time is 8059.31 sec
# Validation loss: 0.8054, Validation accuracy: 0.7880
# Epoch 40: progress time is 10745.18 sec
# Validation loss: 0.7154, Validation accuracy: 0.8048
# 2번 자르고 fine tuning을 시작합니다.
# 2번 pruning 이후 남은 node 는 : (tensor(2356., device='cuda:3'), tensor(2356., device='cuda:3'))
# Epoch 50: progress time is 13424.08 sec
# Validation loss: 0.9822, Validation accuracy: 0.7444
# Epoch 60: progress time is 16105.06 sec
# Validation loss: 0.8050, Validation accuracy: 0.7868
# Epoch 70: progress time is 18787.62 sec
# Validation loss: 0.6968, Validation accuracy: 0.8168
# Epoch 80: progress time is 21470.14 sec
# Validation loss: 0.7153, Validation accuracy: 0.8176
# 3번 자르고 fine tuning을 시작합니다.
# 3번 pruning 이후 남은 node 는 : (tensor(1708., device='cuda:3'), tensor(1708., device='cuda:3'))
# Epoch 90: progress time is 24147.24 sec
# Validation loss: 0.9302, Validation accuracy: 0.7684
# Epoch 100: progress time is 26824.28 sec
# Validation loss: 0.9448, Validation accuracy: 0.7668
# Epoch 110: progress time is 29502.03 sec
# Validation loss: 0.9553, Validation accuracy: 0.7656
# Epoch 120: progress time is 32179.61 sec
# Validation loss: 1.0303, Validation accuracy: 0.7532
# 4번 자르고 fine tuning을 시작합니다.
# 4번 pruning 이후 남은 node 는 : (tensor(1236., device='cuda:3'), tensor(1236., device='cuda:3'))
# Epoch 130: progress time is 34852.52 sec
# Validation loss: 1.4276, Validation accuracy: 0.6236
# Epoch 140: progress time is 37524.4 sec
# Validation loss: 1.6565, Validation accuracy: 0.6032
# Epoch 150: progress time is 40195.86 sec
# Validation loss: 1.4015, Validation accuracy: 0.6428
# Epoch 160: progress time is 42868.16 sec
# Validation loss: 1.5927, Validation accuracy: 0.6188
# 5번 자르고 fine tuning을 시작합니다.
# 5번 pruning 이후 남은 node 는 : (tensor(896., device='cuda:3'), tensor(896., device='cuda:3'))
# Epoch 170: progress time is 45536.99 sec
# Validation loss: 1.6572, Validation accuracy: 0.5672
# Epoch 180: progress time is 48222.89 sec
# Validation loss: 1.7375, Validation accuracy: 0.5760
# Epoch 190: progress time is 50895.33 sec
# Validation loss: 1.4701, Validation accuracy: 0.6104
# Epoch 200: progress time is 53565.74 sec
# Validation loss: 1.6614, Validation accuracy: 0.5788
# ==> Optimization finished! Best validation accuracy: 0.8280
# Total examples is 10000, correct examples is 7778; Test accuracy: 0.7778

# %% [markdown]
# ## 결과확인

# %%
for lr in [0.004, 0.02]:
    model = Wide_ResNet(28, basic, 0.3, 100).to(device)        
    ## test
    checkpoint_path = f"./save_seed{seed}_CIFAR100/28x{basic}_0.8_multistepLR_lr{lr}.pth"
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['state_dict'])
    test_model(model)   
for lr in [0.004, 0.02]:
    model = Wide_ResNet(28, basic, 0.3, 100).to(device)        
    ## test
    checkpoint_path = f"./save_seed{seed}_CIFAR100/28x{basic}_0.8_cosine_lr{lr}.pth"
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['state_dict'])
    test_model(model)
# Out:
# | Wide-Resnet 28x10
# Total examples is 10000, correct examples is 7768; Test accuracy: 0.7768
# | Wide-Resnet 28x10
# Total examples is 10000, correct examples is 7686; Test accuracy: 0.7686
# | Wide-Resnet 28x10
# Total examples is 10000, correct examples is 7894; Test accuracy: 0.7894
# | Wide-Resnet 28x10
# Total examples is 10000, correct examples is 7778; Test accuracy: 0.7778

# %%
##scheduler 실행 : cosineannealingLR
fine_tuning(model, mode = '28x10_0.8_CIFAR10_scheduler_cosine_lr0.1*0.2', EPOCHS = 200)
# Out:
# 최초 node의 갯수 : (tensor(3252., device='cuda:1'), tensor(3252., device='cuda:1'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 pruning 이후 남은 node 는 : (tensor(2356., device='cuda:1'), tensor(2356., device='cuda:1'))
# Epoch 10: progress time is 2478.68 sec
# Validation loss: 0.2617, Validation accuracy: 0.9108
# Epoch 20: progress time is 4955.91 sec
# Validation loss: 0.2866, Validation accuracy: 0.9164
# Epoch 30: progress time is 7431.12 sec
# Validation loss: 0.2915, Validation accuracy: 0.9196
# Epoch 40: progress time is 9905.82 sec
# Validation loss: 0.3297, Validation accuracy: 0.9140
# 41번 자르고 fine tuning을 시작합니다.
# 41번 pruning 이후 남은 node 는 : (tensor(1708., device='cuda:1'), tensor(1708., device='cuda:1'))
# Epoch 50: progress time is 12357.39 sec
# Validation loss: 0.2436, Validation accuracy: 0.9308
# Epoch 60: progress time is 14807.99 sec
# Validation loss: 0.1996, Validation accuracy: 0.9428
# Epoch 70: progress time is 17254.84 sec
# Validation loss: 0.1908, Validation accuracy: 0.9496
# Epoch 80: progress time is 19712.82 sec
# Validation loss: 0.1688, Validation accuracy: 0.9552
# 81번 자르고 fine tuning을 시작합니다.
# 81번 pruning 이후 남은 node 는 : (tensor(1236., device='cuda:1'), tensor(1236., device='cuda:1'))
# Epoch 90: progress time is 22155.8 sec
# Validation loss: 0.2075, Validation accuracy: 0.9396
# Epoch 100: progress time is 24595.93 sec
# Validation loss: 0.1954, Validation accuracy: 0.9448
# Epoch 110: progress time is 27036.58 sec
# Validation loss: 0.1896, Validation accuracy: 0.9440
# Epoch 120: progress time is 29478.56 sec
# Validation loss: 0.2533, Validation accuracy: 0.9324
# 121번 자르고 fine tuning을 시작합니다.
# 121번 pruning 이후 남은 node 는 : (tensor(896., device='cuda:1'), tensor(896., device='cuda:1'))
# Epoch 130: progress time is 31905.13 sec
# Validation loss: 0.3386, Validation accuracy: 0.8968
# Epoch 140: progress time is 34328.41 sec
# Validation loss: 0.4534, Validation accuracy: 0.8712
# Epoch 150: progress time is 36753.3 sec
# Validation loss: 0.3068, Validation accuracy: 0.8992
# Epoch 160: progress time is 39171.88 sec
# Validation loss: 0.5298, Validation accuracy: 0.8436
# 161번 자르고 fine tuning을 시작합니다.
# 161번 pruning 이후 남은 node 는 : (tensor(648., device='cuda:1'), tensor(648., device='cuda:1'))
# Epoch 170: progress time is 41578.93 sec
# Validation loss: 0.7173, Validation accuracy: 0.7624
# Epoch 180: progress time is 43987.93 sec
# Validation loss: 0.5657, Validation accuracy: 0.8152
# Epoch 190: progress time is 46401.38 sec
# Validation loss: 0.4093, Validation accuracy: 0.8720
# Epoch 200: progress time is 48815.73 sec
# Validation loss: 0.4216, Validation accuracy: 0.8576
# ==> Optimization finished! Best validation accuracy: 0.9552
# Wide_ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#   (M_relu): M_relu()
#   (layer1): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(16, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(16, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(160, 320, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(320, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(320, 640, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=640, out_features=10, bias=True)
# )

# %%
##scheduler 실행 : cosineannealingLR
fine_tuning(model, mode = '28x10_0.8_CIFAR10_scheduler_mult_lr0.1*0.2*0.2', EPOCHS = 200)
# Out:
# 최초 node의 갯수 : (tensor(4480., device='cuda:1'), tensor(4480., device='cuda:1'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 pruning 이후 남은 node 는 : (tensor(3252., device='cuda:1'), tensor(3252., device='cuda:1'))
# Epoch 10: progress time is 2499.79 sec
# Validation loss: 0.1489, Validation accuracy: 0.9588
# Epoch 20: progress time is 4998.29 sec
# Validation loss: 0.1762, Validation accuracy: 0.9528
# Epoch 30: progress time is 7501.47 sec
# Validation loss: 0.1696, Validation accuracy: 0.9496
# Epoch 40: progress time is 10075.34 sec
# Validation loss: 0.1866, Validation accuracy: 0.9524
# 41번 자르고 fine tuning을 시작합니다.
# 41번 pruning 이후 남은 node 는 : (tensor(2356., device='cuda:1'), tensor(2356., device='cuda:1'))
# Epoch 50: progress time is 12541.16 sec
# Validation loss: 0.2398, Validation accuracy: 0.9316
# Epoch 60: progress time is 15070.15 sec
# Validation loss: 0.2241, Validation accuracy: 0.9348
# Epoch 70: progress time is 17543.05 sec
# Validation loss: 0.1592, Validation accuracy: 0.9588
# Epoch 80: progress time is 20019.73 sec
# Validation loss: 0.1501, Validation accuracy: 0.9616
# 81번 자르고 fine tuning을 시작합니다.
# 81번 pruning 이후 남은 node 는 : (tensor(1708., device='cuda:1'), tensor(1708., device='cuda:1'))
# Epoch 90: progress time is 22474.1 sec
# Validation loss: 0.1831, Validation accuracy: 0.9472
# Epoch 100: progress time is 24926.04 sec
# Validation loss: 0.1907, Validation accuracy: 0.9508
# Epoch 110: progress time is 27378.19 sec
# Validation loss: 0.1844, Validation accuracy: 0.9524
# Epoch 120: progress time is 29829.5 sec
# Validation loss: 0.1935, Validation accuracy: 0.9476
# 121번 자르고 fine tuning을 시작합니다.
# 121번 pruning 이후 남은 node 는 : (tensor(1236., device='cuda:1'), tensor(1236., device='cuda:1'))
# Epoch 130: progress time is 32265.95 sec
# Validation loss: 0.2381, Validation accuracy: 0.9284
# Epoch 140: progress time is 34700.66 sec
# Validation loss: 0.2225, Validation accuracy: 0.9384
# Epoch 150: progress time is 37140.72 sec
# Validation loss: 0.2065, Validation accuracy: 0.9404
# Epoch 160: progress time is 39576.88 sec
# Validation loss: 0.2357, Validation accuracy: 0.9340
# 161번 자르고 fine tuning을 시작합니다.
# 161번 pruning 이후 남은 node 는 : (tensor(896., device='cuda:1'), tensor(896., device='cuda:1'))
# Epoch 170: progress time is 41999.52 sec
# Validation loss: 0.3040, Validation accuracy: 0.9064
# Epoch 180: progress time is 44424.99 sec
# Validation loss: 0.2827, Validation accuracy: 0.9156
# Epoch 190: progress time is 46844.04 sec
# Validation loss: 0.2608, Validation accuracy: 0.9260
# Epoch 200: progress time is 49266.51 sec
# Validation loss: 0.2667, Validation accuracy: 0.9164
# ==> Optimization finished! Best validation accuracy: 0.9616
# Wide_ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#   (M_relu): M_relu()
#   (layer1): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(16, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(16, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(160, 320, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(320, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(320, 640, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=640, out_features=10, bias=True)
# )

# %%
##scheduler 실행 : multistepLR
fine_tuning(model, mode = mode, EPOCHS = 200)
# Out:
# 최초 node의 갯수 : (tensor(4480., device='cuda:3'), tensor(4480., device='cuda:3'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 pruning 이후 남은 node 는 : (tensor(3252., device='cuda:3'), tensor(3252., device='cuda:3'))
# Epoch 10: progress time is 2620.03 sec
# Validation loss: 0.1136, Validation accuracy: 0.9736
# Epoch 20: progress time is 5241.29 sec
# Validation loss: 0.1016, Validation accuracy: 0.9792
# Epoch 30: progress time is 7857.89 sec
# Validation loss: 0.1461, Validation accuracy: 0.9636
# Epoch 40: progress time is 10477.37 sec
# Validation loss: 0.1902, Validation accuracy: 0.9556
# 2번 자르고 fine tuning을 시작합니다.
# 2번 pruning 이후 남은 node 는 : (tensor(2356., device='cuda:3'), tensor(2356., device='cuda:3'))
# Epoch 50: progress time is 13093.88 sec
# Validation loss: 0.7010, Validation accuracy: 0.8104
# Epoch 60: progress time is 15715.67 sec
# Validation loss: 0.6139, Validation accuracy: 0.8340
# Epoch 70: progress time is 18335.23 sec
# Validation loss: 0.4811, Validation accuracy: 0.8696
# Epoch 80: progress time is 20956.56 sec
# Validation loss: 0.4811, Validation accuracy: 0.8752
# 3번 자르고 fine tuning을 시작합니다.
# 3번 pruning 이후 남은 node 는 : (tensor(1708., device='cuda:3'), tensor(1708., device='cuda:3'))
# Epoch 90: progress time is 23553.08 sec
# Validation loss: 0.7566, Validation accuracy: 0.8036
# Epoch 100: progress time is 26143.11 sec
# Validation loss: 0.7492, Validation accuracy: 0.8060
# Epoch 110: progress time is 28739.22 sec
# Validation loss: 0.7104, Validation accuracy: 0.8132
# Epoch 120: progress time is 31333.12 sec
# Validation loss: 0.7250, Validation accuracy: 0.8040
# 4번 자르고 fine tuning을 시작합니다.
# 4번 pruning 이후 남은 node 는 : (tensor(1236., device='cuda:3'), tensor(1236., device='cuda:3'))
# Epoch 130: progress time is 33912.11 sec
# Validation loss: 1.0292, Validation accuracy: 0.7384
# Epoch 140: progress time is 36491.28 sec
# Validation loss: 0.9959, Validation accuracy: 0.7520
# Epoch 150: progress time is 39070.67 sec
# Validation loss: 1.0106, Validation accuracy: 0.7512
# Epoch 160: progress time is 41646.63 sec
# Validation loss: 0.9897, Validation accuracy: 0.7560
# 5번 자르고 fine tuning을 시작합니다.
# 5번 pruning 이후 남은 node 는 : (tensor(896., device='cuda:3'), tensor(896., device='cuda:3'))
# Epoch 170: progress time is 44211.45 sec
# Validation loss: 1.5442, Validation accuracy: 0.6188
# Epoch 180: progress time is 46771.52 sec
# Validation loss: 1.3221, Validation accuracy: 0.6744
# Epoch 190: progress time is 49334.93 sec
# Validation loss: 1.2869, Validation accuracy: 0.6872
# Epoch 200: progress time is 51893.64 sec
# Validation loss: 1.2512, Validation accuracy: 0.7000
# ==> Optimization finished! Best validation accuracy: 0.9792
# Wide_ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#   (M_relu): M_relu()
#   (layer1): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(16, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(16, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(160, 320, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(320, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(320, 640, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=640, out_features=100, bias=True)
# )

# %%
##scheduler 실행 : cosineannealingLR, lr=0.1*0.2*0.2
fine_tuning(model, mode = mode, EPOCHS = 200)
# Out:
# 최초 node의 갯수 : (tensor(4480., device='cuda:3'), tensor(4480., device='cuda:3'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 pruning 이후 남은 node 는 : (tensor(3252., device='cuda:3'), tensor(3252., device='cuda:3'))
# Epoch 10: progress time is 2595.28 sec
# Validation loss: 0.1058, Validation accuracy: 0.9760
# Epoch 20: progress time is 5224.15 sec
# Validation loss: 0.1111, Validation accuracy: 0.9792
# Epoch 30: progress time is 7852.25 sec
# Validation loss: 0.1430, Validation accuracy: 0.9688
# Epoch 40: progress time is 10468.09 sec
# Validation loss: 0.1145, Validation accuracy: 0.9772
# 2번 자르고 fine tuning을 시작합니다.
# 2번 pruning 이후 남은 node 는 : (tensor(2356., device='cuda:3'), tensor(2356., device='cuda:3'))
# Epoch 50: progress time is 13049.68 sec
# Validation loss: 0.4808, Validation accuracy: 0.8652
# Epoch 60: progress time is 15613.49 sec
# Validation loss: 0.4036, Validation accuracy: 0.8860
# Epoch 70: progress time is 18193.58 sec
# Validation loss: 0.4175, Validation accuracy: 0.8880
# Epoch 80: progress time is 20779.77 sec
# Validation loss: 0.3848, Validation accuracy: 0.9012
# 3번 자르고 fine tuning을 시작합니다.
# 3번 pruning 이후 남은 node 는 : (tensor(1708., device='cuda:3'), tensor(1708., device='cuda:3'))
# Epoch 90: progress time is 23348.82 sec
# Validation loss: 0.6957, Validation accuracy: 0.8108
# Epoch 100: progress time is 25905.85 sec
# Validation loss: 0.7021, Validation accuracy: 0.8204
# Epoch 110: progress time is 28467.04 sec
# Validation loss: 0.7332, Validation accuracy: 0.8092
# Epoch 120: progress time is 31038.66 sec
# Validation loss: 0.6980, Validation accuracy: 0.8188
# 4번 자르고 fine tuning을 시작합니다.
# 4번 pruning 이후 남은 node 는 : (tensor(1236., device='cuda:3'), tensor(1236., device='cuda:3'))
# Epoch 130: progress time is 33582.48 sec
# Validation loss: 1.1697, Validation accuracy: 0.6968
# Epoch 140: progress time is 36124.61 sec
# Validation loss: 1.1693, Validation accuracy: 0.6912
# Epoch 150: progress time is 38673.79 sec
# Validation loss: 1.1920, Validation accuracy: 0.6844
# Epoch 160: progress time is 41222.04 sec
# Validation loss: 1.3409, Validation accuracy: 0.6728
# 5번 자르고 fine tuning을 시작합니다.
# 5번 pruning 이후 남은 node 는 : (tensor(896., device='cuda:3'), tensor(896., device='cuda:3'))
# Epoch 170: progress time is 43750.78 sec
# Validation loss: 1.5470, Validation accuracy: 0.5860
# Epoch 180: progress time is 46288.9 sec
# Validation loss: 1.3628, Validation accuracy: 0.6416
# Epoch 190: progress time is 48820.27 sec
# Validation loss: 1.3544, Validation accuracy: 0.6492
# Epoch 200: progress time is 51348.12 sec
# Validation loss: 1.3429, Validation accuracy: 0.6604
# ==> Optimization finished! Best validation accuracy: 0.9828
# Wide_ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#   (M_relu): M_relu()
#   (layer1): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(16, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(16, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(160, 320, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(320, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(320, 640, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=640, out_features=100, bias=True)
# )

# %%
##scheduler 실행 : cosineannealingLR, lr = 0.1*0.2
fine_tuning(model, mode = mode, EPOCHS = 200)
# Out:
# 최초 node의 갯수 : (tensor(4480., device='cuda:3'), tensor(4480., device='cuda:3'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 pruning 이후 남은 node 는 : (tensor(3252., device='cuda:3'), tensor(3252., device='cuda:3'))
# Epoch 10: progress time is 2607.76 sec
# Validation loss: 0.7816, Validation accuracy: 0.7748
# Epoch 20: progress time is 5206.44 sec
# Validation loss: 0.6978, Validation accuracy: 0.8052
# Epoch 30: progress time is 7806.79 sec
# Validation loss: 0.8532, Validation accuracy: 0.7760
# Epoch 40: progress time is 10411.74 sec
# Validation loss: 0.7553, Validation accuracy: 0.8052
# 2번 자르고 fine tuning을 시작합니다.
# 2번 pruning 이후 남은 node 는 : (tensor(2356., device='cuda:3'), tensor(2356., device='cuda:3'))
# Epoch 50: progress time is 12988.85 sec
# Validation loss: 0.9377, Validation accuracy: 0.7548
# Epoch 60: progress time is 15563.48 sec
# Validation loss: 0.7732, Validation accuracy: 0.7972
# Epoch 70: progress time is 18132.83 sec
# Validation loss: 0.7062, Validation accuracy: 0.8152
# Epoch 80: progress time is 20711.01 sec
# Validation loss: 0.6946, Validation accuracy: 0.8224
# 3번 자르고 fine tuning을 시작합니다.
# 3번 pruning 이후 남은 node 는 : (tensor(1708., device='cuda:3'), tensor(1708., device='cuda:3'))
# Epoch 90: progress time is 23266.09 sec
# Validation loss: 0.8677, Validation accuracy: 0.7844
# Epoch 100: progress time is 25819.66 sec
# Validation loss: 0.8864, Validation accuracy: 0.7752
# Epoch 110: progress time is 28372.5 sec
# Validation loss: 0.8728, Validation accuracy: 0.7804
# Epoch 120: progress time is 30923.09 sec
# Validation loss: 0.9221, Validation accuracy: 0.7772
# 4번 자르고 fine tuning을 시작합니다.
# 4번 pruning 이후 남은 node 는 : (tensor(1236., device='cuda:3'), tensor(1236., device='cuda:3'))
# Epoch 130: progress time is 33454.47 sec
# Validation loss: 1.4500, Validation accuracy: 0.6012
# Epoch 140: progress time is 35987.14 sec
# Validation loss: 1.3000, Validation accuracy: 0.6452
# Epoch 150: progress time is 38521.88 sec
# Validation loss: 1.5830, Validation accuracy: 0.6212
# Epoch 160: progress time is 41055.57 sec
# Validation loss: 1.4149, Validation accuracy: 0.6540
# 5번 자르고 fine tuning을 시작합니다.
# 5번 pruning 이후 남은 node 는 : (tensor(896., device='cuda:3'), tensor(896., device='cuda:3'))
# Epoch 170: progress time is 43574.95 sec
# Validation loss: 1.7153, Validation accuracy: 0.5616
# Epoch 180: progress time is 46099.59 sec
# Validation loss: 1.5379, Validation accuracy: 0.5936
# Epoch 190: progress time is 48622.71 sec
# Validation loss: 1.6043, Validation accuracy: 0.5880
# Epoch 200: progress time is 51143.71 sec
# Validation loss: 1.5335, Validation accuracy: 0.6016
# ==> Optimization finished! Best validation accuracy: 0.8244
# Wide_ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#   (M_relu): M_relu()
#   (layer1): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(16, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(16, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(160, 320, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(320, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(320, 640, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=640, out_features=100, bias=True)
# )

# %%
##scheduler 실행 : cosineannealingLR, lr = 0.1*0.2*0.2
fine_tuning(model, mode = mode, EPOCHS = 200)
# Out:
# 최초 node의 갯수 : (tensor(4480., device='cuda:0'), tensor(4480., device='cuda:0'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 pruning 이후 남은 node 는 : (tensor(3252., device='cuda:0'), tensor(3252., device='cuda:0'))
# Epoch 10: progress time is 2596.18 sec
# Validation loss: 0.0167, Validation accuracy: 0.9960
# Epoch 20: progress time is 5189.22 sec
# Validation loss: 0.0185, Validation accuracy: 0.9952
# Epoch 30: progress time is 7788.87 sec
# Validation loss: 0.0226, Validation accuracy: 0.9936
# Epoch 40: progress time is 10380.87 sec
# Validation loss: 0.0229, Validation accuracy: 0.9940
# 2번 자르고 fine tuning을 시작합니다.
# 2번 pruning 이후 남은 node 는 : (tensor(2356., device='cuda:0'), tensor(2356., device='cuda:0'))
# Epoch 50: progress time is 12972.23 sec
# Validation loss: 0.0537, Validation accuracy: 0.9844
# Epoch 60: progress time is 15583.05 sec
# Validation loss: 0.0478, Validation accuracy: 0.9856
# Epoch 70: progress time is 18168.36 sec
# Validation loss: 0.0429, Validation accuracy: 0.9852
# Epoch 80: progress time is 20753.66 sec
# Validation loss: 0.0406, Validation accuracy: 0.9872
# 3번 자르고 fine tuning을 시작합니다.
# 3번 pruning 이후 남은 node 는 : (tensor(1708., device='cuda:0'), tensor(1708., device='cuda:0'))
# Epoch 90: progress time is 23343.08 sec
# Validation loss: 0.0892, Validation accuracy: 0.9716
# Epoch 100: progress time is 25988.97 sec
# Validation loss: 0.0850, Validation accuracy: 0.9736
# Epoch 110: progress time is 28572.38 sec
# Validation loss: 0.0821, Validation accuracy: 0.9756
# Epoch 120: progress time is 31152.7 sec
# Validation loss: 0.0942, Validation accuracy: 0.9724
# 4번 자르고 fine tuning을 시작합니다.
# 4번 pruning 이후 남은 node 는 : (tensor(1236., device='cuda:0'), tensor(1236., device='cuda:0'))
# Epoch 130: progress time is 33728.05 sec
# Validation loss: 0.2105, Validation accuracy: 0.9280
# Epoch 140: progress time is 36302.79 sec
# Validation loss: 0.2185, Validation accuracy: 0.9280
# Epoch 150: progress time is 38877.97 sec
# Validation loss: 0.2345, Validation accuracy: 0.9328
# Epoch 160: progress time is 41453.3 sec
# Validation loss: 0.2672, Validation accuracy: 0.9220
# 5번 자르고 fine tuning을 시작합니다.
# 5번 pruning 이후 남은 node 는 : (tensor(896., device='cuda:0'), tensor(896., device='cuda:0'))
# Epoch 170: progress time is 44027.64 sec
# Validation loss: 0.3460, Validation accuracy: 0.8816
# Epoch 180: progress time is 46601.18 sec
# Validation loss: 0.3888, Validation accuracy: 0.8820
# Epoch 190: progress time is 49175.48 sec
# Validation loss: 0.2932, Validation accuracy: 0.9124
# Epoch 200: progress time is 51748.11 sec
# Validation loss: 0.2783, Validation accuracy: 0.9220
# ==> Optimization finished! Best validation accuracy: 0.9964
# Wide_ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#   (M_relu): M_relu()
#   (layer1): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(16, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(16, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(160, 320, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(320, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(320, 640, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=640, out_features=10, bias=True)
# )

# %% [markdown]
# ## seed 10

# %%
## cifar100
##scheduler 실행 : cosineannealingLR, lr = 0.1*0.2*0.2
fine_tuning(model, mode = mode, EPOCHS = 200)
# Out:
# 최초 node의 갯수 : (tensor(4480., device='cuda:1'), tensor(4480., device='cuda:1'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 pruning 이후 남은 node 는 : (tensor(3252., device='cuda:1'), tensor(3252., device='cuda:1'))
# Epoch 10: progress time is 2690.82 sec
# Validation loss: 0.1442, Validation accuracy: 0.9656
# Epoch 20: progress time is 5379.31 sec
# Validation loss: 0.1399, Validation accuracy: 0.9708
# Epoch 30: progress time is 8068.43 sec
# Validation loss: 0.1449, Validation accuracy: 0.9732
# Epoch 40: progress time is 10757.5 sec
# Validation loss: 0.1437, Validation accuracy: 0.9720
# 2번 자르고 fine tuning을 시작합니다.
# 2번 pruning 이후 남은 node 는 : (tensor(2356., device='cuda:1'), tensor(2356., device='cuda:1'))
# Epoch 50: progress time is 13444.32 sec
# Validation loss: 0.5256, Validation accuracy: 0.8688
# Epoch 60: progress time is 16127.6 sec
# Validation loss: 0.4229, Validation accuracy: 0.8980
# Epoch 70: progress time is 18805.88 sec
# Validation loss: 0.4375, Validation accuracy: 0.8896
# Epoch 80: progress time is 21483.61 sec
# Validation loss: 0.4010, Validation accuracy: 0.8964
# 3번 자르고 fine tuning을 시작합니다.
# 3번 pruning 이후 남은 node 는 : (tensor(1709., device='cuda:1'), tensor(1708., device='cuda:1'))
# Epoch 90: progress time is 24346.71 sec
# Validation loss: 0.7117, Validation accuracy: 0.8180
# Epoch 100: progress time is 27148.12 sec
# Validation loss: 0.6916, Validation accuracy: 0.8308
# Epoch 110: progress time is 29821.26 sec
# Validation loss: 0.7503, Validation accuracy: 0.8144
# Epoch 120: progress time is 32494.54 sec
# Validation loss: 0.7592, Validation accuracy: 0.8128
# 4번 자르고 fine tuning을 시작합니다.
# 4번 pruning 이후 남은 node 는 : (tensor(1237., device='cuda:1'), tensor(1236., device='cuda:1'))
# Epoch 130: progress time is 35165.26 sec
# Validation loss: 1.3667, Validation accuracy: 0.6608
# Epoch 140: progress time is 37836.05 sec
# Validation loss: 1.1980, Validation accuracy: 0.6836
# Epoch 150: progress time is 40505.99 sec
# Validation loss: 1.2652, Validation accuracy: 0.6908
# Epoch 160: progress time is 43177.0 sec
# Validation loss: 1.4053, Validation accuracy: 0.6640
# 5번 자르고 fine tuning을 시작합니다.
# 5번 pruning 이후 남은 node 는 : (tensor(897., device='cuda:1'), tensor(896., device='cuda:1'))
# Epoch 170: progress time is 45846.36 sec
# Validation loss: 1.7817, Validation accuracy: 0.5332
# Epoch 180: progress time is 48514.91 sec
# Validation loss: 1.3587, Validation accuracy: 0.6336
# Epoch 190: progress time is 51183.01 sec
# Validation loss: 1.3465, Validation accuracy: 0.6524
# Epoch 200: progress time is 53850.43 sec
# Validation loss: 1.2999, Validation accuracy: 0.6696
# ==> Optimization finished! Best validation accuracy: 0.9804
# Wide_ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#   (M_relu): M_relu()
#   (layer1): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(16, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(16, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(160, 320, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(320, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(320, 640, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=640, out_features=100, bias=True)
# )

# %%
## cifar100
##scheduler 실행 : cosineannealingLR, lr = 0.1*0.2
fine_tuning(model, mode = mode, EPOCHS = 200)
# Out:
# 최초 node의 갯수 : (tensor(4480., device='cuda:1'), tensor(4480., device='cuda:1'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 pruning 이후 남은 node 는 : (tensor(3252., device='cuda:1'), tensor(3252., device='cuda:1'))
# Epoch 10: progress time is 2816.52 sec
# Validation loss: 0.8322, Validation accuracy: 0.7748
# Epoch 20: progress time is 5628.69 sec
# Validation loss: 0.9617, Validation accuracy: 0.7424
# Epoch 30: progress time is 8439.33 sec
# Validation loss: 0.8241, Validation accuracy: 0.7836
# Epoch 40: progress time is 11249.75 sec
# Validation loss: 0.7671, Validation accuracy: 0.7960
# 2번 자르고 fine tuning을 시작합니다.
# 2번 pruning 이후 남은 node 는 : (tensor(2356., device='cuda:1'), tensor(2356., device='cuda:1'))
# Epoch 50: progress time is 14050.75 sec
# Validation loss: 0.9712, Validation accuracy: 0.7532
# Epoch 60: progress time is 16851.54 sec
# Validation loss: 0.7995, Validation accuracy: 0.7972
# Epoch 70: progress time is 19654.75 sec
# Validation loss: 0.7082, Validation accuracy: 0.8208
# Epoch 80: progress time is 22455.18 sec
# Validation loss: 0.7211, Validation accuracy: 0.8212
# 3번 자르고 fine tuning을 시작합니다.
# 3번 pruning 이후 남은 node 는 : (tensor(1708., device='cuda:1'), tensor(1708., device='cuda:1'))
# Epoch 90: progress time is 25251.99 sec
# Validation loss: 0.9022, Validation accuracy: 0.7772
# Epoch 100: progress time is 28045.62 sec
# Validation loss: 0.9014, Validation accuracy: 0.7808
# Epoch 110: progress time is 30838.75 sec
# Validation loss: 0.9137, Validation accuracy: 0.7796
# Epoch 120: progress time is 33632.35 sec
# Validation loss: 1.0096, Validation accuracy: 0.7608
# 4번 자르고 fine tuning을 시작합니다.
# 4번 pruning 이후 남은 node 는 : (tensor(1236., device='cuda:1'), tensor(1236., device='cuda:1'))
# Epoch 130: progress time is 36422.42 sec
# Validation loss: 1.3969, Validation accuracy: 0.6352
# Epoch 140: progress time is 39211.97 sec
# Validation loss: 1.4051, Validation accuracy: 0.6396
# Epoch 150: progress time is 42002.44 sec
# Validation loss: 1.4552, Validation accuracy: 0.6376
# Epoch 160: progress time is 44792.77 sec
# Validation loss: 1.4082, Validation accuracy: 0.6572
# 5번 자르고 fine tuning을 시작합니다.
# 5번 pruning 이후 남은 node 는 : (tensor(896., device='cuda:1'), tensor(896., device='cuda:1'))
# Epoch 170: progress time is 47581.13 sec
# Validation loss: 1.7248, Validation accuracy: 0.5324
# Epoch 180: progress time is 50368.89 sec
# Validation loss: 1.6111, Validation accuracy: 0.5748
# Epoch 190: progress time is 53346.23 sec
# Validation loss: 1.6057, Validation accuracy: 0.5884
# Epoch 200: progress time is 56277.4 sec
# Validation loss: 1.5315, Validation accuracy: 0.6072
# ==> Optimization finished! Best validation accuracy: 0.8308
# Wide_ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#   (M_relu): M_relu()
#   (layer1): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(16, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(16, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(160, 320, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): M_BasicBlock(
#       (conv1): Conv2d(320, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential(
#         (0): Conv2d(320, 640, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (2): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#     (3): M_BasicBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu1): M_relu()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (M_relu2): M_relu()
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=640, out_features=100, bias=True)
# )

# %% [markdown]
# ## 결과 확인

# %%
## cifar10
check_prune = torch.load("./saved_tuning/28x10_0.8_CIFAR10_scheduler_cosine_lr0.1*0.2.pth")

model.load_state_dict(check_prune['state_dict'])

test_model(model)

send_email('28x10_0.8_CIFAR10_scheduler_cosine finished')
# Out:
# Total examples is 10000, correct examples is 9489; Test accuracy: 0.9489

# %%
## cifar10
check_prune = torch.load("./saved_tuning/28x10_0.8_CIFAR10_scheduler_mult_lr0.1*0.2*0.2.pth")

model.load_state_dict(check_prune['state_dict'])

test_model(model)

send_email('28x10_0.8_CIFAR10_scheduler_cosine finished')
# Out:
# Total examples is 10000, correct examples is 9536; Test accuracy: 0.9536

# %% [markdown]
# ## CIFAR100

# %%
## cifar100
check_prune = torch.load("./saved_tuning_CIFAR100/28x10_0.8_multistepLR_lr0.1*0.2*0.2.pth")

model.load_state_dict(check_prune['state_dict'])

test_model(model)

# send_email('28x10_0.6_multistepLR_lr0.1*0.2*0.2 finished')
# Out:
# Total examples is 10000, correct examples is 7828; Test accuracy: 0.7828

# %%
## cifar100
check_prune = torch.load("./saved_tuning_CIFAR100/28x10_0.8_cosine_lr0.1*0.2*0.2.pth")

model.load_state_dict(check_prune['state_dict'])

test_model(model)

# send_email('28x10_0.6_multistepLR_lr0.1*0.2*0.2 finished')
# Out:
# Total examples is 10000, correct examples is 7817; Test accuracy: 0.7817

# %%
## cifar100
check_prune = torch.load("./saved_tuning_CIFAR100/28x10_0.8_cosine_lr0.1*0.2.pth")

model.load_state_dict(check_prune['state_dict'])

test_model(model)

# send_email('28x10_0.6_multistepLR_lr0.1*0.2*0.2 finished')
# Out:
# Total examples is 10000, correct examples is 7805; Test accuracy: 0.7805

# %% [markdown]
# ## seed10

# %%
## cifar10
check_prune = torch.load("./save_seed10_CIFAR10/28x10_0.8_cosine_lr0.1*0.2*0.2.pth")

model.load_state_dict(check_prune['state_dict'])

test_model(model)

# send_email('28x2_multistepLR_lr0.1*0.2*0.2 finished')
# Out:
# Total examples is 10000, correct examples is 9533; Test accuracy: 0.9533

# %%
## cifar100
check_prune = torch.load("./save_seed10_CIFAR100/28x10_0.8_cosine_lr0.1*0.2*0.2.pth")

model.load_state_dict(check_prune['state_dict'])

test_model(model)

# send_email('28x2_multistepLR_lr0.1*0.2*0.2 finished')
# Out:
# Total examples is 10000, correct examples is 7804; Test accuracy: 0.7804

# %%
## cifar100
check_prune = torch.load("./save_seed10_CIFAR100/28x10_0.8_cosine_lr0.1*0.2.pth")

model.load_state_dict(check_prune['state_dict'])

test_model(model)

# send_email('28x2_multistepLR_lr0.1*0.2*0.2 finished')
# Out:
# Total examples is 10000, correct examples is 7755; Test accuracy: 0.7755
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
