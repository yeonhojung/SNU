# %%
from new_model import *

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    torch.manual_seed(seed)
    if device == 'cuda':
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
#CIFAR 100 : Data 다운로드 경로지정
batch_size = 128

#Data Process
transform_train = transforms.Compose([transforms.RandomCrop(32, padding=4),transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(),transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))]) 

transform_val = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))]) 

transform_test = transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))]) 

train_CIFAR100 = torchvision.datasets.CIFAR100(root='../data', train=True, download=True, transform=transform_train)

test_CIFAR100 = torchvision.datasets.CIFAR100(root='../data', train=False, download=True, transform=transform_test)

num_train = int(1.0 * len(train_CIFAR100) * 95 / 100)
num_val = len(train_CIFAR100) - num_train
train_CIFAR100, val_CIFAR100 = torch.utils.data.random_split(train_CIFAR100, [num_train, num_val])

train_loader = torch.utils.data.DataLoader(train_CIFAR100, batch_size=batch_size, shuffle=True, num_workers=2) #num_workers는 데이터 로드시 sub process 몇개 쓸거냐 
val_loader = torch.utils.data.DataLoader(val_CIFAR100, batch_size=batch_size,shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_CIFAR100, batch_size=batch_size, shuffle=True, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def node_prune(model, pruning_ratio):
    for layer in model.modules():
        if isinstance(layer, M_BasicBlock):
            # calculate cutoff value
            nonzero_vals = layer.get_2norm()[0][layer.M_relu1.active != 0]
            cutoff1 = torch.quantile(nonzero_vals, pruning_ratio)

            # set inactive nodes to 0
            layer.M_relu1.active.data[layer.get_2norm()[0] < cutoff1] *= 0
            
            # calculate cutoff value
            nonzero_vals = layer.get_2norm()[1][layer.M_relu2.active != 0]
            cutoff2 = torch.quantile(nonzero_vals, pruning_ratio)

            # set inactive nodes to 0
            layer.M_relu2.active.data[layer.get_2norm()[1] < cutoff2] *= 0

# %%
## fine_tuning
def fine_tuning(model, mode, EPOCHS, INITIAL_LR):
    # total number of training epochs
    CHECKPOINT_PATH = "./10times_CIFAR100"

    best_val_acc = 0
    current_learning_rate = INITIAL_LR
    
    remaining_node1 = sum([sum(layer.M_relu1.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
    remaining_node2 = sum([sum(layer.M_relu2.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
    print(f'최초 node의 갯수 : {remaining_node1, remaining_node2}')    

    print("==> Training starts!")
    start = time.time()
    optimizer = torch.optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)
    scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[60, 120, 160], gamma=0.2)
    # scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=0)    
    for i in range(EPOCHS):
        if i % (EPOCHS/10) == 0 : #10번 자르는 거
            print(f'{int(i//(EPOCHS/10)+1)}번 자르고 fine tuning을 시작합니다.')
            node_prune(model, ratio)
            
            remaining_node1 = sum([sum(layer.M_relu1.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
            remaining_node2 = sum([sum(layer.M_relu2.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])

            print(f'{int(i//(EPOCHS/10)+1)}번 자르고 난 후 남은 node 는 : {(remaining_node1, remaining_node2)}')
        
        '''
        train loop
        '''            
        model.train()
        
        # this help you compute the training accuracy
        total_examples = 0
        correct_examples = 0

        train_loss = 0 # track training loss if you want

        # Train the model for 1 epoch.
        for batch_idx, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.to(device).float(), targets.to(device).long() #inputs과 targets는 gpu로 계산

            # compute the output and loss
            y_preds = model(inputs)        
            loss = criterion(y_preds,targets)
            train_loss += loss.item()

            # zero the gradient
            optimizer.zero_grad()

            # backpropagation
            loss.backward()

            # apply gradient and update the weights
            optimizer.step()

            # count the number of correctly predicted samples in the current batch
            y_preds_class = torch.argmax(y_preds, dim=1)
            correct_examples += (targets == y_preds_class).sum().item()
            total_examples += targets.size(0)

        scheduler.step()    #스케쥴러 사용해보기
            
        avg_loss_tr = train_loss / len(train_loader) ###
        avg_acc_tr = correct_examples / total_examples ### 

                                                      
        '''
        validation loop
        '''
                                                      
        # switch to eval mode
        model.eval()
        total_examples = 0
        correct_examples = 0
        val_loss = 0 # again, track the validation loss if you want
        
        # disable gradient during validation, which can save GPU memory
        with torch.no_grad():
            for batch_idx, (inputs, targets) in enumerate(val_loader):
                inputs, targets = inputs.to(device).float(), targets.to(device).long()

                # compute the output and loss
                y_preds = model(inputs)        
                loss = criterion(y_preds,targets)
                val_loss += loss.item()

                # count the number of correctly predicted samples in the current batch
                y_preds_class = torch.argmax(y_preds, dim=1)
                correct_examples += (targets == y_preds_class).sum().item()
                total_examples += targets.size(0)

        avg_loss_val = val_loss / len(val_loader)
        avg_acc_val = correct_examples / total_examples

                                                      
        # save the model checkpoint
        if avg_acc_val > best_val_acc:
            best_val_acc = avg_acc_val
            if not os.path.exists(CHECKPOINT_PATH):
                os.makedirs(CHECKPOINT_PATH)

            state = {'state_dict': model.state_dict(),
                     'epoch': i,
                     'lr': current_learning_rate}
            
            torch.save(state, os.path.join(CHECKPOINT_PATH, '{}.pth'.format(mode)))        
    
        if i % 100 == 99 :  
            end = time.time()
            diff_time = round(end - start,2)
            print("Epoch %d:" %(i+1), f"progress time is {diff_time} sec")
            print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss_val, avg_acc_val))
    print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")                       

    return model

# %%
###8. test_model
def test_model(model):
    model.to(device)
    model.eval()

    total_examples = 0
    correct_examples = 0
    softmax = torch.nn.Softmax(dim=1)

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(test_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            pred = model(inputs)
            total_examples += inputs.shape[0]

            out = softmax(pred)
            out = torch.max(out, 1)

            correct_examples += torch.sum(targets==out[1]).cpu().data.numpy().tolist()

    avg_acc = correct_examples / total_examples
    print("Total examples is {}, correct examples is {}; Test accuracy: {}".format(total_examples, correct_examples, avg_acc))

# %% [markdown]
# ## 모델지정

# %%
device = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")

MOMENTUM = 0.9

REG = 5e-4

criterion = nn.CrossEntropyLoss()

##5번 자를때 
# ratio = 1-0.5**0.194
##10번 자를때
ratio = 1-0.5**0.08744

# %% [markdown]
# # multistepLR

# %% [markdown]
# ## cifar100

# %%
lr = 0.02
basic = 2
for seed in [10, 100, 777] :
    set_seed(seed)
    model = Wide_ResNet(28, basic, 0.3, 100).to(device)        
    ## train 
    checkpoint = torch.load(f"../1.Wide_ResNet_model/saved_model/WR_28x{basic}_cifar100.pth")
    model.load_state_dict(checkpoint['state_dict'])

    fine_tuning(model, mode=f"28x{basic}_multistepLR_lr{lr}_seed{seed}", EPOCHS=1000, INITIAL_LR=lr)

    ## test
    checkpoint_path = f"./10times_CIFAR100/28x{basic}_multistepLR_lr{lr}_seed{seed}.pth"
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['state_dict'])
    test_model(model)
# Out:
# | Wide-Resnet 28x2
# 최초 node의 갯수 : (tensor(896., device='cuda:2'), tensor(896., device='cuda:2'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 자르고 난 후 남은 node 는 : (tensor(840., device='cuda:2'), tensor(840., device='cuda:2'))
# Epoch 100: progress time is 3031.85 sec
# Validation loss: 0.7950, Validation accuracy: 0.7920
# 2번 자르고 fine tuning을 시작합니다.
# 2번 자르고 난 후 남은 node 는 : (tensor(788., device='cuda:2'), tensor(788., device='cuda:2'))
# Epoch 200: progress time is 6339.32 sec
# Validation loss: 0.8599, Validation accuracy: 0.7748
# 3번 자르고 fine tuning을 시작합니다.
# 3번 자르고 난 후 남은 node 는 : (tensor(736., device='cuda:2'), tensor(736., device='cuda:2'))
# Epoch 300: progress time is 9838.46 sec
# Validation loss: 0.9692, Validation accuracy: 0.7520
# 4번 자르고 fine tuning을 시작합니다.
# 4번 자르고 난 후 남은 node 는 : (tensor(688., device='cuda:2'), tensor(688., device='cuda:2'))
# Epoch 400: progress time is 12700.74 sec
# Validation loss: 1.1406, Validation accuracy: 0.7176
# 5번 자르고 fine tuning을 시작합니다.
# 5번 자르고 난 후 남은 node 는 : (tensor(644., device='cuda:2'), tensor(644., device='cuda:2'))
# Epoch 500: progress time is 15462.78 sec
# Validation loss: 1.1779, Validation accuracy: 0.7028
# 6번 자르고 fine tuning을 시작합니다.
# 6번 자르고 난 후 남은 node 는 : (tensor(600., device='cuda:2'), tensor(600., device='cuda:2'))
# Epoch 600: progress time is 18221.31 sec
# Validation loss: 1.1842, Validation accuracy: 0.7208
# 7번 자르고 fine tuning을 시작합니다.
# 7번 자르고 난 후 남은 node 는 : (tensor(556., device='cuda:2'), tensor(556., device='cuda:2'))
# Epoch 700: progress time is 20977.29 sec
# Validation loss: 1.2846, Validation accuracy: 0.6932
# 8번 자르고 fine tuning을 시작합니다.
# 8번 자르고 난 후 남은 node 는 : (tensor(520., device='cuda:2'), tensor(520., device='cuda:2'))
# Epoch 800: progress time is 23738.99 sec
# Validation loss: 1.3612, Validation accuracy: 0.6696
# 9번 자르고 fine tuning을 시작합니다.
# 9번 자르고 난 후 남은 node 는 : (tensor(484., device='cuda:2'), tensor(484., device='cuda:2'))
# Epoch 900: progress time is 26489.2 sec
# Validation loss: 1.3510, Validation accuracy: 0.6712
# 10번 자르고 fine tuning을 시작합니다.
# 10번 자르고 난 후 남은 node 는 : (tensor(452., device='cuda:2'), tensor(452., device='cuda:2'))
# Epoch 1000: progress time is 29243.86 sec
# Validation loss: 1.4199, Validation accuracy: 0.6532
# ==> Optimization finished! Best validation accuracy: 0.8056
# Total examples is 10000, correct examples is 7370; Test accuracy: 0.737
# | Wide-Resnet 28x2
# 최초 node의 갯수 : (tensor(896., device='cuda:2'), tensor(896., device='cuda:2'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 자르고 난 후 남은 node 는 : (tensor(840., device='cuda:2'), tensor(840., device='cuda:2'))
# Epoch 100: progress time is 2773.62 sec
# Validation loss: 0.8207, Validation accuracy: 0.7780
# 2번 자르고 fine tuning을 시작합니다.
# 2번 자르고 난 후 남은 node 는 : (tensor(788., device='cuda:2'), tensor(788., device='cuda:2'))
# Epoch 200: progress time is 5551.13 sec
# Validation loss: 0.9242, Validation accuracy: 0.7660
# 3번 자르고 fine tuning을 시작합니다.
# 3번 자르고 난 후 남은 node 는 : (tensor(736., device='cuda:2'), tensor(736., device='cuda:2'))
# Epoch 300: progress time is 8321.76 sec
# Validation loss: 1.0104, Validation accuracy: 0.7488
# 4번 자르고 fine tuning을 시작합니다.
# 4번 자르고 난 후 남은 node 는 : (tensor(688., device='cuda:2'), tensor(688., device='cuda:2'))
# Epoch 400: progress time is 11086.3 sec
# Validation loss: 1.0773, Validation accuracy: 0.7228
# 5번 자르고 fine tuning을 시작합니다.
# 5번 자르고 난 후 남은 node 는 : (tensor(644., device='cuda:2'), tensor(644., device='cuda:2'))
# Epoch 500: progress time is 13854.42 sec
# Validation loss: 1.1755, Validation accuracy: 0.7108
# 6번 자르고 fine tuning을 시작합니다.
# 6번 자르고 난 후 남은 node 는 : (tensor(600., device='cuda:2'), tensor(600., device='cuda:2'))
# Epoch 600: progress time is 16610.43 sec
# Validation loss: 1.2676, Validation accuracy: 0.6876
# 7번 자르고 fine tuning을 시작합니다.
# 7번 자르고 난 후 남은 node 는 : (tensor(556., device='cuda:2'), tensor(556., device='cuda:2'))
# Epoch 700: progress time is 19363.49 sec
# Validation loss: 1.3153, Validation accuracy: 0.6812
# 8번 자르고 fine tuning을 시작합니다.
# 8번 자르고 난 후 남은 node 는 : (tensor(520., device='cuda:2'), tensor(520., device='cuda:2'))
# Epoch 800: progress time is 22109.37 sec
# Validation loss: 1.3248, Validation accuracy: 0.6720
# 9번 자르고 fine tuning을 시작합니다.
# 9번 자르고 난 후 남은 node 는 : (tensor(484., device='cuda:2'), tensor(484., device='cuda:2'))
# Epoch 900: progress time is 24874.46 sec
# Validation loss: 1.4317, Validation accuracy: 0.6432
# 10번 자르고 fine tuning을 시작합니다.
# 10번 자르고 난 후 남은 node 는 : (tensor(452., device='cuda:2'), tensor(452., device='cuda:2'))
# Epoch 1000: progress time is 27626.29 sec
# Validation loss: 1.3872, Validation accuracy: 0.6680
# ==> Optimization finished! Best validation accuracy: 0.7892
# Total examples is 10000, correct examples is 7397; Test accuracy: 0.7397
# | Wide-Resnet 28x2
# 최초 node의 갯수 : (tensor(896., device='cuda:2'), tensor(896., device='cuda:2'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 자르고 난 후 남은 node 는 : (tensor(840., device='cuda:2'), tensor(840., device='cuda:2'))
# Epoch 100: progress time is 2790.28 sec
# Validation loss: 0.8192, Validation accuracy: 0.7768
# 2번 자르고 fine tuning을 시작합니다.
# 2번 자르고 난 후 남은 node 는 : (tensor(788., device='cuda:2'), tensor(788., device='cuda:2'))
# Epoch 200: progress time is 5578.5 sec
# Validation loss: 0.9182, Validation accuracy: 0.7676
# 3번 자르고 fine tuning을 시작합니다.
# 3번 자르고 난 후 남은 node 는 : (tensor(736., device='cuda:2'), tensor(736., device='cuda:2'))
# Epoch 300: progress time is 8365.85 sec
# Validation loss: 1.0485, Validation accuracy: 0.7332
# 4번 자르고 fine tuning을 시작합니다.
# 4번 자르고 난 후 남은 node 는 : (tensor(688., device='cuda:2'), tensor(688., device='cuda:2'))
# Epoch 400: progress time is 11133.98 sec
# Validation loss: 1.1594, Validation accuracy: 0.7140
# 5번 자르고 fine tuning을 시작합니다.
# 5번 자르고 난 후 남은 node 는 : (tensor(644., device='cuda:2'), tensor(644., device='cuda:2'))
# Epoch 500: progress time is 13907.28 sec
# Validation loss: 1.1972, Validation accuracy: 0.7108
# 6번 자르고 fine tuning을 시작합니다.
# 6번 자르고 난 후 남은 node 는 : (tensor(600., device='cuda:2'), tensor(600., device='cuda:2'))
# Epoch 600: progress time is 16691.56 sec
# Validation loss: 1.1906, Validation accuracy: 0.7088
# 7번 자르고 fine tuning을 시작합니다.
# 7번 자르고 난 후 남은 node 는 : (tensor(556., device='cuda:2'), tensor(556., device='cuda:2'))
# Epoch 700: progress time is 19450.27 sec
# Validation loss: 1.3748, Validation accuracy: 0.6688
# 8번 자르고 fine tuning을 시작합니다.
# 8번 자르고 난 후 남은 node 는 : (tensor(520., device='cuda:2'), tensor(520., device='cuda:2'))
# Epoch 800: progress time is 22211.29 sec
# Validation loss: 1.3881, Validation accuracy: 0.6732
# 9번 자르고 fine tuning을 시작합니다.
# 9번 자르고 난 후 남은 node 는 : (tensor(484., device='cuda:2'), tensor(484., device='cuda:2'))
# Epoch 900: progress time is 24966.17 sec
# Validation loss: 1.3845, Validation accuracy: 0.6596
# 10번 자르고 fine tuning을 시작합니다.
# 10번 자르고 난 후 남은 node 는 : (tensor(452., device='cuda:2'), tensor(452., device='cuda:2'))
# Epoch 1000: progress time is 27730.56 sec
# Validation loss: 1.4826, Validation accuracy: 0.6300
# ==> Optimization finished! Best validation accuracy: 0.7968
# Total examples is 10000, correct examples is 7361; Test accuracy: 0.7361

# %% [markdown]
# # Cosine scheduler

# %%
## fine_tuning
def fine_tuning(model, mode, EPOCHS, INITIAL_LR):
    # total number of training epochs
    CHECKPOINT_PATH = "./10times_CIFAR100"

    best_val_acc = 0
    current_learning_rate = INITIAL_LR
    
    remaining_node1 = sum([sum(layer.M_relu1.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
    remaining_node2 = sum([sum(layer.M_relu2.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
    print(f'최초 node의 갯수 : {remaining_node1, remaining_node2}')    

    print("==> Training starts!")
    start = time.time()
    optimizer = torch.optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)
    # scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[60, 120, 160], gamma=0.2)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=0)    
    for i in range(EPOCHS):
        if i % (EPOCHS/10) == 0 : #10번 자르는 거
            print(f'{int(i//(EPOCHS/10)+1)}번 자르고 fine tuning을 시작합니다.')
            node_prune(model, ratio)
            
            remaining_node1 = sum([sum(layer.M_relu1.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
            remaining_node2 = sum([sum(layer.M_relu2.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])

            print(f'{int(i//(EPOCHS/10)+1)}번 자르고 난 후 남은 node 는 : {(remaining_node1, remaining_node2)}')
        
        '''
        train loop
        '''            
        model.train()
        
        # this help you compute the training accuracy
        total_examples = 0
        correct_examples = 0

        train_loss = 0 # track training loss if you want

        # Train the model for 1 epoch.
        for batch_idx, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.to(device).float(), targets.to(device).long() #inputs과 targets는 gpu로 계산

            # compute the output and loss
            y_preds = model(inputs)        
            loss = criterion(y_preds,targets)
            train_loss += loss.item()

            # zero the gradient
            optimizer.zero_grad()

            # backpropagation
            loss.backward()

            # apply gradient and update the weights
            optimizer.step()

            # count the number of correctly predicted samples in the current batch
            y_preds_class = torch.argmax(y_preds, dim=1)
            correct_examples += (targets == y_preds_class).sum().item()
            total_examples += targets.size(0)

        scheduler.step()    #스케쥴러 사용해보기
            
        avg_loss_tr = train_loss / len(train_loader) ###
        avg_acc_tr = correct_examples / total_examples ### 

                                                      
        '''
        validation loop
        '''
                                                      
        # switch to eval mode
        model.eval()
        total_examples = 0
        correct_examples = 0
        val_loss = 0 # again, track the validation loss if you want
        
        # disable gradient during validation, which can save GPU memory
        with torch.no_grad():
            for batch_idx, (inputs, targets) in enumerate(val_loader):
                inputs, targets = inputs.to(device).float(), targets.to(device).long()

                # compute the output and loss
                y_preds = model(inputs)        
                loss = criterion(y_preds,targets)
                val_loss += loss.item()

                # count the number of correctly predicted samples in the current batch
                y_preds_class = torch.argmax(y_preds, dim=1)
                correct_examples += (targets == y_preds_class).sum().item()
                total_examples += targets.size(0)

        avg_loss_val = val_loss / len(val_loader)
        avg_acc_val = correct_examples / total_examples

                                                      
        # save the model checkpoint
        if avg_acc_val > best_val_acc:
            best_val_acc = avg_acc_val
            if not os.path.exists(CHECKPOINT_PATH):
                os.makedirs(CHECKPOINT_PATH)

            state = {'state_dict': model.state_dict(),
                     'epoch': i,
                     'lr': current_learning_rate}
            
            torch.save(state, os.path.join(CHECKPOINT_PATH, '{}.pth'.format(mode)))        
    
        if i % 100 == 99 :  
            end = time.time()
            diff_time = round(end - start,2)
            print("Epoch %d:" %(i+1), f"progress time is {diff_time} sec")
            print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss_val, avg_acc_val))
    print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")                       

    return model

# %% [markdown]
# # cosine

# %% [markdown]
# ## cifar100

# %%
lr = 0.02
basic = 2
for seed in [10, 100, 777] :
    set_seed(seed)
    model = Wide_ResNet(28, basic, 0.3, 100).to(device)        
    ## train 
    checkpoint = torch.load(f"../1.Wide_ResNet_model/saved_model/WR_28x{basic}_cifar100.pth")
    model.load_state_dict(checkpoint['state_dict'])

    fine_tuning(model, mode=f"28x{basic}_cosine_lr{lr}_seed{seed}", EPOCHS=1000, INITIAL_LR=lr)

    ## test
    checkpoint_path = f"./10times_CIFAR100/28x{basic}_cosine_lr{lr}_seed{seed}.pth"
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['state_dict'])
    test_model(model)
# Out:
# | Wide-Resnet 28x2
# 최초 node의 갯수 : (tensor(896., device='cuda:2'), tensor(896., device='cuda:2'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 자르고 난 후 남은 node 는 : (tensor(840., device='cuda:2'), tensor(840., device='cuda:2'))
# Epoch 100: progress time is 2785.66 sec
# Validation loss: 0.7313, Validation accuracy: 0.8108
# 2번 자르고 fine tuning을 시작합니다.
# 2번 자르고 난 후 남은 node 는 : (tensor(788., device='cuda:2'), tensor(788., device='cuda:2'))
# Epoch 200: progress time is 5555.71 sec
# Validation loss: 1.2196, Validation accuracy: 0.6792
# 3번 자르고 fine tuning을 시작합니다.
# 3번 자르고 난 후 남은 node 는 : (tensor(736., device='cuda:2'), tensor(736., device='cuda:2'))
# Epoch 300: progress time is 8323.36 sec
# Validation loss: 0.9723, Validation accuracy: 0.7564
# 4번 자르고 fine tuning을 시작합니다.
# 4번 자르고 난 후 남은 node 는 : (tensor(688., device='cuda:2'), tensor(688., device='cuda:2'))
# Epoch 400: progress time is 11587.09 sec
# Validation loss: 1.3959, Validation accuracy: 0.6536
# 5번 자르고 fine tuning을 시작합니다.
# 5번 자르고 난 후 남은 node 는 : (tensor(644., device='cuda:2'), tensor(644., device='cuda:2'))
# Epoch 500: progress time is 14823.68 sec
# Validation loss: 1.0782, Validation accuracy: 0.7320
# 6번 자르고 fine tuning을 시작합니다.
# 6번 자르고 난 후 남은 node 는 : (tensor(600., device='cuda:2'), tensor(600., device='cuda:2'))
# Epoch 600: progress time is 18151.99 sec
# Validation loss: 1.4413, Validation accuracy: 0.6292
# 7번 자르고 fine tuning을 시작합니다.
# 7번 자르고 난 후 남은 node 는 : (tensor(556., device='cuda:2'), tensor(556., device='cuda:2'))
# Epoch 700: progress time is 20969.56 sec
# Validation loss: 1.1311, Validation accuracy: 0.7264
# 8번 자르고 fine tuning을 시작합니다.
# 8번 자르고 난 후 남은 node 는 : (tensor(520., device='cuda:2'), tensor(520., device='cuda:2'))
# Epoch 800: progress time is 23719.47 sec
# Validation loss: 1.4859, Validation accuracy: 0.6080
# 9번 자르고 fine tuning을 시작합니다.
# 9번 자르고 난 후 남은 node 는 : (tensor(484., device='cuda:2'), tensor(484., device='cuda:2'))
# Epoch 900: progress time is 26480.86 sec
# Validation loss: 1.2368, Validation accuracy: 0.6900
# 10번 자르고 fine tuning을 시작합니다.
# 10번 자르고 난 후 남은 node 는 : (tensor(452., device='cuda:2'), tensor(452., device='cuda:2'))
# Epoch 1000: progress time is 29245.1 sec
# Validation loss: 1.5710, Validation accuracy: 0.5668
# ==> Optimization finished! Best validation accuracy: 0.8148
# Total examples is 10000, correct examples is 7437; Test accuracy: 0.7437
# | Wide-Resnet 28x2
# 최초 node의 갯수 : (tensor(896., device='cuda:2'), tensor(896., device='cuda:2'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 자르고 난 후 남은 node 는 : (tensor(840., device='cuda:2'), tensor(840., device='cuda:2'))
# Epoch 100: progress time is 2877.45 sec
# Validation loss: 0.7727, Validation accuracy: 0.7928
# 2번 자르고 fine tuning을 시작합니다.
# 2번 자르고 난 후 남은 node 는 : (tensor(788., device='cuda:2'), tensor(788., device='cuda:2'))
# Epoch 200: progress time is 6183.06 sec
# Validation loss: 1.2106, Validation accuracy: 0.6756
# 3번 자르고 fine tuning을 시작합니다.
# 3번 자르고 난 후 남은 node 는 : (tensor(736., device='cuda:2'), tensor(736., device='cuda:2'))
# Epoch 300: progress time is 9183.94 sec
# Validation loss: 0.9965, Validation accuracy: 0.7492
# 4번 자르고 fine tuning을 시작합니다.
# 4번 자르고 난 후 남은 node 는 : (tensor(688., device='cuda:2'), tensor(688., device='cuda:2'))
# Epoch 400: progress time is 11946.84 sec
# Validation loss: 1.4498, Validation accuracy: 0.6428
# 5번 자르고 fine tuning을 시작합니다.
# 5번 자르고 난 후 남은 node 는 : (tensor(644., device='cuda:2'), tensor(644., device='cuda:2'))
# Epoch 500: progress time is 14708.91 sec
# Validation loss: 1.1307, Validation accuracy: 0.7304
# 6번 자르고 fine tuning을 시작합니다.
# 6번 자르고 난 후 남은 node 는 : (tensor(600., device='cuda:2'), tensor(600., device='cuda:2'))
# Epoch 600: progress time is 17463.82 sec
# Validation loss: 1.6638, Validation accuracy: 0.5964
# 7번 자르고 fine tuning을 시작합니다.
# 7번 자르고 난 후 남은 node 는 : (tensor(556., device='cuda:2'), tensor(556., device='cuda:2'))
# Epoch 700: progress time is 20223.83 sec
# Validation loss: 1.2039, Validation accuracy: 0.7200
# 8번 자르고 fine tuning을 시작합니다.
# 8번 자르고 난 후 남은 node 는 : (tensor(520., device='cuda:2'), tensor(520., device='cuda:2'))
# Epoch 800: progress time is 22970.84 sec
# Validation loss: 1.5109, Validation accuracy: 0.6052
# 9번 자르고 fine tuning을 시작합니다.
# 9번 자르고 난 후 남은 node 는 : (tensor(484., device='cuda:2'), tensor(484., device='cuda:2'))
# Epoch 900: progress time is 25726.56 sec
# Validation loss: 1.1688, Validation accuracy: 0.6988
# 10번 자르고 fine tuning을 시작합니다.
# 10번 자르고 난 후 남은 node 는 : (tensor(452., device='cuda:2'), tensor(452., device='cuda:2'))
# Epoch 1000: progress time is 28482.93 sec
# Validation loss: 1.5078, Validation accuracy: 0.6020
# ==> Optimization finished! Best validation accuracy: 0.8108
# Total examples is 10000, correct examples is 7380; Test accuracy: 0.738
# | Wide-Resnet 28x2
# 최초 node의 갯수 : (tensor(896., device='cuda:2'), tensor(896., device='cuda:2'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 자르고 난 후 남은 node 는 : (tensor(840., device='cuda:2'), tensor(840., device='cuda:2'))
# Epoch 100: progress time is 2781.23 sec
# Validation loss: 0.7417, Validation accuracy: 0.7972
# 2번 자르고 fine tuning을 시작합니다.
# 2번 자르고 난 후 남은 node 는 : (tensor(788., device='cuda:2'), tensor(788., device='cuda:2'))
# Epoch 200: progress time is 5568.59 sec
# Validation loss: 1.4128, Validation accuracy: 0.6428
# 3번 자르고 fine tuning을 시작합니다.
# 3번 자르고 난 후 남은 node 는 : (tensor(736., device='cuda:2'), tensor(736., device='cuda:2'))
# Epoch 300: progress time is 8351.71 sec
# Validation loss: 1.0212, Validation accuracy: 0.7528
# 4번 자르고 fine tuning을 시작합니다.
# 4번 자르고 난 후 남은 node 는 : (tensor(688., device='cuda:2'), tensor(688., device='cuda:2'))
# Epoch 400: progress time is 11141.42 sec
# Validation loss: 1.2935, Validation accuracy: 0.6696
# 5번 자르고 fine tuning을 시작합니다.
# 5번 자르고 난 후 남은 node 는 : (tensor(644., device='cuda:2'), tensor(644., device='cuda:2'))
# Epoch 500: progress time is 13912.58 sec
# Validation loss: 1.1129, Validation accuracy: 0.7360
# 6번 자르고 fine tuning을 시작합니다.
# 6번 자르고 난 후 남은 node 는 : (tensor(600., device='cuda:2'), tensor(600., device='cuda:2'))
# Epoch 600: progress time is 16679.98 sec
# Validation loss: 1.4525, Validation accuracy: 0.6272
# 7번 자르고 fine tuning을 시작합니다.
# 7번 자르고 난 후 남은 node 는 : (tensor(556., device='cuda:2'), tensor(556., device='cuda:2'))
# Epoch 700: progress time is 19443.55 sec
# Validation loss: 1.1788, Validation accuracy: 0.7240
# 8번 자르고 fine tuning을 시작합니다.
# 8번 자르고 난 후 남은 node 는 : (tensor(520., device='cuda:2'), tensor(520., device='cuda:2'))
# Epoch 800: progress time is 22204.2 sec
# Validation loss: 1.4667, Validation accuracy: 0.6064
# 9번 자르고 fine tuning을 시작합니다.
# 9번 자르고 난 후 남은 node 는 : (tensor(484., device='cuda:2'), tensor(484., device='cuda:2'))
# Epoch 900: progress time is 24966.65 sec
# Validation loss: 1.1857, Validation accuracy: 0.7028
# 10번 자르고 fine tuning을 시작합니다.
# 10번 자르고 난 후 남은 node 는 : (tensor(452., device='cuda:2'), tensor(452., device='cuda:2'))
# Epoch 1000: progress time is 27774.32 sec
# Validation loss: 1.6238, Validation accuracy: 0.5744
# ==> Optimization finished! Best validation accuracy: 0.8072
# Total examples is 10000, correct examples is 7363; Test accuracy: 0.7363

# %% [markdown]
# ## test 결과
#
# ### cifar100

# %%
lr = 0.02
basic = 2
for seed in [10, 100, 777] :
    model = Wide_ResNet(28, basic, 0.3, 100).to(device)        
    ## test
    checkpoint_path = f"./10times_CIFAR100/28x{basic}_multistepLR_lr{lr}_seed{seed}.pth"
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['state_dict'])
    test_model(model)   
for seed in [10, 100, 777] :
    model = Wide_ResNet(28, basic, 0.3, 100).to(device)        
    ## test
    checkpoint_path = f"./10times_CIFAR100/28x{basic}_cosine_lr{lr}_seed{seed}.pth"
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['state_dict'])
    test_model(model)
# Out:
# | Wide-Resnet 28x2
# Total examples is 10000, correct examples is 7370; Test accuracy: 0.737
# | Wide-Resnet 28x2
# Total examples is 10000, correct examples is 7397; Test accuracy: 0.7397
# | Wide-Resnet 28x2
# Total examples is 10000, correct examples is 7361; Test accuracy: 0.7361
# | Wide-Resnet 28x2
# Total examples is 10000, correct examples is 7437; Test accuracy: 0.7437
# | Wide-Resnet 28x2
# Total examples is 10000, correct examples is 7380; Test accuracy: 0.738
# | Wide-Resnet 28x2
# Total examples is 10000, correct examples is 7363; Test accuracy: 0.7363
