# %%
from new_model import *

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    torch.manual_seed(seed)
    if device == 'cuda':
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
#Data 다운로드 경로지정
batch_size = 128


#Data Process 
transform_train = transforms.Compose([transforms.RandomCrop(32, padding=4),transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(),transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))]) 

transform_val = transforms.Compose([transforms.ToTensor(), 
                                    transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010))])

transform_test = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010))])

train_CIFAR10 = torchvision.datasets.CIFAR10(root='../data', train=True, download=True, transform=transform_train)

test_CIFAR10 = torchvision.datasets.CIFAR10(root='../data', train=False, download=True, transform=transform_test)

num_train = int(1.0 * len(train_CIFAR10) * 95 / 100)
num_val = len(train_CIFAR10) - num_train
train_CIFAR10, val_CIFAR10 = torch.utils.data.random_split(train_CIFAR10, [num_train, num_val])

train_loader = torch.utils.data.DataLoader(train_CIFAR10, batch_size=batch_size, shuffle=True, num_workers=2) #num_workers는 데이터 로드시 sub process 몇개 쓸거냐 
val_loader = torch.utils.data.DataLoader(val_CIFAR10, batch_size=batch_size,shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_CIFAR10, batch_size=batch_size, shuffle=True, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def node_prune(model, pruning_ratio):
    for layer in model.modules():
        if isinstance(layer, M_BasicBlock):
            # calculate cutoff value
            nonzero_vals = layer.get_2norm()[0][layer.M_relu1.active != 0]
            cutoff1 = torch.quantile(nonzero_vals, pruning_ratio)

            # set inactive nodes to 0
            layer.M_relu1.active.data[layer.get_2norm()[0] < cutoff1] *= 0
            
            # calculate cutoff value
            nonzero_vals = layer.get_2norm()[1][layer.M_relu2.active != 0]
            cutoff2 = torch.quantile(nonzero_vals, pruning_ratio)

            # set inactive nodes to 0
            layer.M_relu2.active.data[layer.get_2norm()[1] < cutoff2] *= 0

# %%
## fine_tuning
def fine_tuning(model, mode, EPOCHS, INITIAL_LR):
    # total number of training epochs
    CHECKPOINT_PATH = f"./seed_CIFAR10"

    best_val_acc = 0
    current_learning_rate = INITIAL_LR
    
    remaining_node1 = sum([sum(layer.M_relu1.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
    remaining_node2 = sum([sum(layer.M_relu2.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
    print(f'최초 node의 갯수 : {remaining_node1, remaining_node2}')    

    print("==> Training starts!")
    start = time.time()
    optimizer = torch.optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)
    scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[60, 120, 160], gamma=0.2)
    # scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=0)    
    for i in range(EPOCHS):  
        
        if i % (EPOCHS/10) == 0 : #10번 자르는 거
            print(f'{int(i//(EPOCHS/10)+1)}번 자르고 fine tuning을 시작합니다.')
            node_prune(model, ratio)
            
            remaining_node1 = sum([sum(layer.M_relu1.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
            remaining_node2 = sum([sum(layer.M_relu2.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])

            print(f'{int(i//(EPOCHS/10)+1)}번 자르고 난 후 남은 node 는 : {(remaining_node1, remaining_node2)}')

        '''
        train loop
        '''            
        model.train()
        
        # this help you compute the training accuracy
        total_examples = 0
        correct_examples = 0

        train_loss = 0 # track training loss if you want

        # Train the model for 1 epoch.
        for batch_idx, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.to(device).float(), targets.to(device).long() #inputs과 targets는 gpu로 계산

            # compute the output and loss
            y_preds = model(inputs)        
            loss = criterion(y_preds,targets)
            train_loss += loss.item()

            # zero the gradient
            optimizer.zero_grad()

            # backpropagation
            loss.backward()

            # apply gradient and update the weights
            optimizer.step()

            # count the number of correctly predicted samples in the current batch
            y_preds_class = torch.argmax(y_preds, dim=1)
            correct_examples += (targets == y_preds_class).sum().item()
            total_examples += targets.size(0)

        scheduler.step()    #스케쥴러 사용해보기
            
        avg_loss_tr = train_loss / len(train_loader) ###
        avg_acc_tr = correct_examples / total_examples ### 

                                                      
        '''
        validation loop
        '''
                                                      
        # switch to eval mode
        model.eval()
        total_examples = 0
        correct_examples = 0
        val_loss = 0 # again, track the validation loss if you want
        
        # disable gradient during validation, which can save GPU memory
        with torch.no_grad():
            for batch_idx, (inputs, targets) in enumerate(val_loader):
                inputs, targets = inputs.to(device).float(), targets.to(device).long()

                # compute the output and loss
                y_preds = model(inputs)        
                loss = criterion(y_preds,targets)
                val_loss += loss.item()

                # count the number of correctly predicted samples in the current batch
                y_preds_class = torch.argmax(y_preds, dim=1)
                correct_examples += (targets == y_preds_class).sum().item()
                total_examples += targets.size(0)

        avg_loss_val = val_loss / len(val_loader)
        avg_acc_val = correct_examples / total_examples

                                                      
        # save the model checkpoint
        if i >= 0.8 * EPOCHS :
            if avg_acc_val > best_val_acc:
                best_val_acc = avg_acc_val
            if not os.path.exists(CHECKPOINT_PATH):
                os.makedirs(CHECKPOINT_PATH)

            state = {'state_dict': model.state_dict(),
                     'epoch': i,
                     'lr': current_learning_rate}
            
            torch.save(state, os.path.join(CHECKPOINT_PATH, '{}.pth'.format(mode)))        
    
        if i % 100 == 99 :  
            end = time.time()
            diff_time = round(end - start,2)
            print("Epoch %d:" %(i+1), f"progress time is {diff_time} sec")
            print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss_val, avg_acc_val))
    print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")                       

    return model

# %%
###8. test_model
def test_model(model):
    model.to(device)
    model.eval()

    total_examples = 0
    correct_examples = 0
    softmax = torch.nn.Softmax(dim=1)

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(test_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            pred = model(inputs)
            total_examples += inputs.shape[0]

            out = softmax(pred)
            out = torch.max(out, 1)

            correct_examples += torch.sum(targets==out[1]).cpu().data.numpy().tolist()

    avg_acc = correct_examples / total_examples
    print("Total examples is {}, correct examples is {}; Test accuracy: {}".format(total_examples, correct_examples, avg_acc))

# %% [markdown]
# ## 모델지정

# %%
device = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")

MOMENTUM = 0.9

REG = 5e-4

criterion = nn.CrossEntropyLoss()

ratio = 1-0.5**0.08744 #28x2
# ratio = 1-0.5**0.0938 #28x4

# %% [markdown]
# # multistepLR

# %% [markdown]
# ## cifar10

# %%
lr = 0.02
basic = 2
for seed in [10,100,777] :
    set_seed(seed)
    
    model = Wide_ResNet(28, basic, 0.3, 10).to(device)        
    ## train
    checkpoint = torch.load(f"../1.Wide_ResNet_model/saved_model/WR_28x{basic}_cifar10.pth")
    model.load_state_dict(checkpoint['state_dict'])

    fine_tuning(model, mode=f"28x{basic}_cosine_lr{lr}_seed{seed}", EPOCHS=1000, INITIAL_LR=lr)

    ## test
    checkpoint_path = f"./practice_CIFAR10/28x{basic}_multistepLR_lr{lr}_seed{seed}.pth"
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['state_dict'])
    test_model(model)
# Out:
# | Wide-Resnet 28x2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 6
#       3 for seed in [10,100,777] :
#       4     set_seed(seed)
# ----> 6     model = Wide_ResNet(28, basic, 0.3, 10).to(device)
#       7     ## train
#       8     checkpoint = torch.load(f"../1.Wide_ResNet_model/saved_model/WR_28x{basic}_cifar10.pth")
#
# File ~/final_saved_model/3.node_sparse(fine tuning)/new_model.py:122, in Wide_ResNet.__init__(self, depth, widen_factor, dropout_rate, num_classes)
#     120 self.conv1 = conv3x3(3,nStages[0]) #3, 16
#     121 self.bn1 = nn.BatchNorm2d(nStages[0], momentum=0.9) #16
# --> 122 self.M_relu = M_relu(nStages[0],nStages[0]) #16, 16
#     123 self.layer1 = self._wide_layer(M_BasicBlock, nStages[1], n, dropout_rate, stride=1)
#     124 self.layer2 = self._wide_layer(M_BasicBlock, nStages[2], n, dropout_rate, stride=2)
#
# File ~/final_saved_model/3.node_sparse(fine tuning)/new_model.py:32, in M_relu.__init__(self, input_dim, init_active_dim)
#      29 self.input_dim = input_dim
#      30 self.init_active_dim = init_active_dim
# ---> 32 self.active = nn.Parameter(torch.cuda.FloatTensor([1]*self.init_active_dim), requires_grad=False)
#
# KeyboardInterrupt:

# %% [markdown]
# # Cosine scheduler

# %%
## fine_tuning
def fine_tuning(model, mode, EPOCHS, INITIAL_LR):
    # total number of training epochs
    CHECKPOINT_PATH = f"./seed_CIFAR10"

    best_val_acc = 0
    current_learning_rate = INITIAL_LR
    
    remaining_node1 = sum([sum(layer.M_relu1.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
    remaining_node2 = sum([sum(layer.M_relu2.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
    print(f'최초 node의 갯수 : {remaining_node1, remaining_node2}')    

    print("==> Training starts!")
    start = time.time()
    optimizer = torch.optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)
    # scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[60, 120, 160], gamma=0.2)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=0)    
    for i in range(EPOCHS):  
        
        if i % (EPOCHS/10) == 0 : #10번 자르는 거
            print(f'{int(i//(EPOCHS/10)+1)}번 자르고 fine tuning을 시작합니다.')
            node_prune(model, ratio)
            
            remaining_node1 = sum([sum(layer.M_relu1.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])
            remaining_node2 = sum([sum(layer.M_relu2.active) for layer in model.modules() if isinstance(layer, M_BasicBlock)])

            print(f'{int(i//(EPOCHS/10)+1)}번 자르고 난 후 남은 node 는 : {(remaining_node1, remaining_node2)}')

        '''
        train loop
        '''            
        model.train()
        
        # this help you compute the training accuracy
        total_examples = 0
        correct_examples = 0

        train_loss = 0 # track training loss if you want

        # Train the model for 1 epoch.
        for batch_idx, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.to(device).float(), targets.to(device).long() #inputs과 targets는 gpu로 계산

            # compute the output and loss
            y_preds = model(inputs)        
            loss = criterion(y_preds,targets)
            train_loss += loss.item()

            # zero the gradient
            optimizer.zero_grad()

            # backpropagation
            loss.backward()

            # apply gradient and update the weights
            optimizer.step()

            # count the number of correctly predicted samples in the current batch
            y_preds_class = torch.argmax(y_preds, dim=1)
            correct_examples += (targets == y_preds_class).sum().item()
            total_examples += targets.size(0)

        scheduler.step()    #스케쥴러 사용해보기
            
        avg_loss_tr = train_loss / len(train_loader) ###
        avg_acc_tr = correct_examples / total_examples ### 

                                                      
        '''
        validation loop
        '''
                                                      
        # switch to eval mode
        model.eval()
        total_examples = 0
        correct_examples = 0
        val_loss = 0 # again, track the validation loss if you want
        
        # disable gradient during validation, which can save GPU memory
        with torch.no_grad():
            for batch_idx, (inputs, targets) in enumerate(val_loader):
                inputs, targets = inputs.to(device).float(), targets.to(device).long()

                # compute the output and loss
                y_preds = model(inputs)        
                loss = criterion(y_preds,targets)
                val_loss += loss.item()

                # count the number of correctly predicted samples in the current batch
                y_preds_class = torch.argmax(y_preds, dim=1)
                correct_examples += (targets == y_preds_class).sum().item()
                total_examples += targets.size(0)

        avg_loss_val = val_loss / len(val_loader)
        avg_acc_val = correct_examples / total_examples

                                                      
        # save the model checkpoint
        if i >= 0.8 * EPOCHS :
            if avg_acc_val > best_val_acc:
                best_val_acc = avg_acc_val
            if not os.path.exists(CHECKPOINT_PATH):
                os.makedirs(CHECKPOINT_PATH)

            state = {'state_dict': model.state_dict(),
                     'epoch': i,
                     'lr': current_learning_rate}
            
            torch.save(state, os.path.join(CHECKPOINT_PATH, '{}.pth'.format(mode)))        
    
        if i % 100 == 99 :  
            end = time.time()
            diff_time = round(end - start,2)
            print("Epoch %d:" %(i+1), f"progress time is {diff_time} sec")
            print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss_val, avg_acc_val))
    print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")                       

    return model

# %% [markdown]
# # cosine

# %% [markdown]
# ## cifar10

# %%
lr = 0.02
basic = 2
for seed in [10,100,777] :
    set_seed(seed)
    
    model = Wide_ResNet(28, basic, 0.3, 10).to(device)        
    ## train
    checkpoint = torch.load(f"../1.Wide_ResNet_model/saved_model/WR_28x{basic}_cifar10.pth")
    model.load_state_dict(checkpoint['state_dict'])

    fine_tuning(model, mode=f"28x{basic}_cosine_lr{lr}_seed{seed}", EPOCHS=2000, INITIAL_LR=lr)

    ## test
    checkpoint_path = f"./seed_CIFAR10/28x{basic}_cosine_lr{lr}_seed{seed}.pth"
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['state_dict'])
    test_model(model)
# Out:
# | Wide-Resnet 28x2
# 최초 node의 갯수 : (tensor(896., device='cuda:2'), tensor(896., device='cuda:2'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 자르고 난 후 남은 node 는 : (tensor(840., device='cuda:2'), tensor(840., device='cuda:2'))
# Epoch 100: progress time is 2759.57 sec
# Validation loss: 0.1414, Validation accuracy: 0.9584
# Epoch 200: progress time is 5813.78 sec
# Validation loss: 0.2893, Validation accuracy: 0.9068
# 2번 자르고 fine tuning을 시작합니다.
# 2번 자르고 난 후 남은 node 는 : (tensor(788., device='cuda:2'), tensor(788., device='cuda:2'))
# Epoch 300: progress time is 9540.29 sec
# Validation loss: 0.1629, Validation accuracy: 0.9524
# Epoch 400: progress time is 12339.11 sec
# Validation loss: 0.3405, Validation accuracy: 0.8988
# 3번 자르고 fine tuning을 시작합니다.
# 3번 자르고 난 후 남은 node 는 : (tensor(736., device='cuda:2'), tensor(736., device='cuda:2'))
# Epoch 500: progress time is 15090.7 sec
# Validation loss: 0.1783, Validation accuracy: 0.9496
# Epoch 600: progress time is 17843.32 sec
# Validation loss: 0.3094, Validation accuracy: 0.9080
# 4번 자르고 fine tuning을 시작합니다.
# 4번 자르고 난 후 남은 node 는 : (tensor(688., device='cuda:2'), tensor(688., device='cuda:2'))
# Epoch 700: progress time is 20579.34 sec
# Validation loss: 0.2133, Validation accuracy: 0.9464
# Epoch 800: progress time is 23317.42 sec
# Validation loss: 0.3610, Validation accuracy: 0.8952
# 5번 자르고 fine tuning을 시작합니다.
# 5번 자르고 난 후 남은 node 는 : (tensor(644., device='cuda:2'), tensor(644., device='cuda:2'))
# Epoch 900: progress time is 26058.25 sec
# Validation loss: 0.2148, Validation accuracy: 0.9420
# Epoch 1000: progress time is 28801.25 sec
# Validation loss: 0.3200, Validation accuracy: 0.9024
# 6번 자르고 fine tuning을 시작합니다.
# 6번 자르고 난 후 남은 node 는 : (tensor(600., device='cuda:2'), tensor(600., device='cuda:2'))
# Epoch 1100: progress time is 31532.18 sec
# Validation loss: 0.2236, Validation accuracy: 0.9424
# Epoch 1200: progress time is 34449.08 sec
# Validation loss: 0.3664, Validation accuracy: 0.8840
# 7번 자르고 fine tuning을 시작합니다.
# 7번 자르고 난 후 남은 node 는 : (tensor(556., device='cuda:2'), tensor(556., device='cuda:2'))
# Epoch 1300: progress time is 37807.69 sec
# Validation loss: 0.2189, Validation accuracy: 0.9412
# Epoch 1400: progress time is 41704.24 sec
# Validation loss: 0.3703, Validation accuracy: 0.8820
# 8번 자르고 fine tuning을 시작합니다.
# 8번 자르고 난 후 남은 node 는 : (tensor(520., device='cuda:2'), tensor(520., device='cuda:2'))
# Epoch 1500: progress time is 45116.13 sec
# Validation loss: 0.2184, Validation accuracy: 0.9452
# Epoch 1600: progress time is 47835.08 sec
# Validation loss: 0.3409, Validation accuracy: 0.8972
# 9번 자르고 fine tuning을 시작합니다.
# 9번 자르고 난 후 남은 node 는 : (tensor(484., device='cuda:2'), tensor(484., device='cuda:2'))
# Epoch 1700: progress time is 50545.94 sec
# Validation loss: 0.2637, Validation accuracy: 0.9308
# Epoch 1800: progress time is 53263.7 sec
# Validation loss: 0.3882, Validation accuracy: 0.8796
# 10번 자르고 fine tuning을 시작합니다.
# 10번 자르고 난 후 남은 node 는 : (tensor(452., device='cuda:2'), tensor(452., device='cuda:2'))
# Epoch 1900: progress time is 55986.65 sec
# Validation loss: 0.2764, Validation accuracy: 0.9308
# Epoch 2000: progress time is 58710.12 sec
# Validation loss: 0.3524, Validation accuracy: 0.8916
# ==> Optimization finished! Best validation accuracy: 0.9420
# Total examples is 10000, correct examples is 8906; Test accuracy: 0.8906
# | Wide-Resnet 28x2
# 최초 node의 갯수 : (tensor(896., device='cuda:2'), tensor(896., device='cuda:2'))
# ==> Training starts!
# 1번 자르고 fine tuning을 시작합니다.
# 1번 자르고 난 후 남은 node 는 : (tensor(840., device='cuda:2'), tensor(840., device='cuda:2'))
# Epoch 100: progress time is 2732.5 sec
# Validation loss: 0.1345, Validation accuracy: 0.9624
# Epoch 200: progress time is 5461.22 sec
# Validation loss: 0.2720, Validation accuracy: 0.9144
# 2번 자르고 fine tuning을 시작합니다.
# 2번 자르고 난 후 남은 node 는 : (tensor(788., device='cuda:2'), tensor(788., device='cuda:2'))
# Epoch 300: progress time is 8202.3 sec
# Validation loss: 0.1831, Validation accuracy: 0.9492
# Epoch 400: progress time is 10937.62 sec
# Validation loss: 0.3001, Validation accuracy: 0.9156
# 3번 자르고 fine tuning을 시작합니다.
# 3번 자르고 난 후 남은 node 는 : (tensor(736., device='cuda:2'), tensor(736., device='cuda:2'))
# Epoch 500: progress time is 13679.12 sec
# Validation loss: 0.1914, Validation accuracy: 0.9452
# Epoch 600: progress time is 16592.28 sec
# Validation loss: 0.3913, Validation accuracy: 0.8832
# 4번 자르고 fine tuning을 시작합니다.
# 4번 자르고 난 후 남은 node 는 : (tensor(688., device='cuda:2'), tensor(688., device='cuda:2'))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 11
#       8 checkpoint = torch.load(f"../1.Wide_ResNet_model/saved_model/WR_28x{basic}_cifar10.pth")
#       9 model.load_state_dict(checkpoint['state_dict'])
# ---> 11 fine_tuning(model, mode=f"28x{basic}_cosine_lr{lr}_seed{seed}", EPOCHS=2000, INITIAL_LR=lr)
#      13 ## test
#      14 checkpoint_path = f"./seed_CIFAR10/28x{basic}_cosine_lr{lr}_seed{seed}.pth"
#
# Cell In[10], line 45, in fine_tuning(model, mode, EPOCHS, INITIAL_LR)
#      42 inputs, targets = inputs.to(device).float(), targets.to(device).long() #inputs과 targets는 gpu로 계산
#      44 # compute the output and loss
# ---> 45 y_preds = model(inputs)
#      46 loss = criterion(y_preds,targets)
#      47 train_loss += loss.item()
#
# File /usr/local/miniconda3/envs/nine/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/final_saved_model/3.node_sparse(fine tuning)/new_model.py:142, in Wide_ResNet.forward(self, x)
#     140 out = self.M_relu(self.bn1(self.conv1(x)))
#     141 out = self.layer1(out)
# --> 142 out = self.layer2(out)
#     143 out = self.layer3(out)
#     144 out = F.avg_pool2d(out, 8)
#
# File /usr/local/miniconda3/envs/nine/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/miniconda3/envs/nine/lib/python3.9/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File /usr/local/miniconda3/envs/nine/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/final_saved_model/3.node_sparse(fine tuning)/new_model.py:82, in M_BasicBlock.forward(self, x)
#      81 def forward(self, x):
# ---> 82     out = self.M_relu1(self.bn1(self.conv1(x)))
#      83     out = self.bn2(self.conv2(out))
#      84     out += self.shortcut(x)
#
# File /usr/local/miniconda3/envs/nine/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/final_saved_model/3.node_sparse(fine tuning)/new_model.py:40, in M_relu.forward(self, x)
#      38 elif len(x.shape)==4:
#      39     M = self.active.view(1,-1,1,1)
# ---> 40     return M * F.relu(x)
#
# File /usr/local/miniconda3/envs/nine/lib/python3.9/site-packages/torch/nn/functional.py:1457, in relu(input, inplace)
#    1455     result = torch.relu_(input)
#    1456 else:
# -> 1457     result = torch.relu(input)
#    1458 return result
#
# KeyboardInterrupt:
